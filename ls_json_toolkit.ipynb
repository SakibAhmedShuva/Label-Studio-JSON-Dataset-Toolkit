# %%
import re
from collections import defaultdict, Counter

# %%
import json
import re
from collections import defaultdict, Counter

class LabelStudioEditor:
    def __init__(self, file_path, encoding='utf-8'):
        self.file_path = file_path
        self.encoding = encoding
        try:
            self.data = self._load_data()
        except UnicodeDecodeError:
            # If UTF-8 fails, try with different encodings
            encodings_to_try = ['latin1', 'iso-8859-1', 'cp1252']
            for enc in encodings_to_try:
                try:
                    self.encoding = enc
                    self.data = self._load_data()
                    print(f"Successfully loaded file using {enc} encoding")
                    break
                except UnicodeDecodeError:
                    continue
            else:
                raise UnicodeDecodeError(f"Could not read file with any of these encodings: utf-8, {', '.join(encodings_to_try)}")

    def _load_data(self):
        with open(self.file_path, 'r', encoding=self.encoding) as f:
            return json.load(f)

    def view_annotations(self):
        for item in self.data:
            text = item['data']['text']
            print(f"Document Text: {text}")
            for annotation in item['annotations']:
                for result in annotation['result']:
                    print(f"Label: {result['value']['labels'][0]}, "
                          f"Text: {text[result['value']['start']:result['value']['end']]}")
            print("-" * 50)

    def label_stats(self):
        label_counter = Counter()
        total_annotations = 0

        for item in self.data:
            for annotation in item['annotations']:
                for result in annotation['result']:
                    label = result['value']['labels'][0]
                    label_counter[label] += 1
                    total_annotations += 1

        for label, count in label_counter.items():
            print(f"Label: {label}, Count: {count}")
        
        print(f"\nTotal number of annotations found: {total_annotations}")
        print(f"Total number of unique tags: {len(label_counter)}")

    def search_by_label(self, label):
        matches = []
        
        for item in self.data:
            text = item['data']['text']
            for annotation in item['annotations']:
                label_matches = [
                    result for result in annotation['result'] 
                    if label in result['value']['labels']
                ]
                
                if label_matches:
                    for match in label_matches:
                        matched_text = text[match['value']['start']:match['value']['end']]
                        matches.append({
                            'text': matched_text,
                            'label': label
                        })

        # Print matches
        for match in matches:
            print(f"Label: {match['label']}, Text: {match['text']}")

        print(f"\nNumber of tokens found with label '{label}': {len(matches)}")

    def search_by_token(self, token):
        matches = []
        
        for item in self.data:
            text = item['data']['text']
            if token in text:
                matches.append({
                    'text': text,
                    'annotations': [
                        result for annotation in item['annotations'] 
                        for result in annotation['result']
                    ]
                })

        # Print matches
        for match in matches:
            print(f"Text containing '{token}':")
            print(match['text'])
            for ann in match['annotations']:
                print(f"  Label: {ann['value']['labels'][0]}, "
                      f"Matched Text: {match['text'][ann['value']['start']:ann['value']['end']]}")
            print("-" * 50)

        print(f"\nNumber of documents containing '{token}': {len(matches)}")

    def remove_label(self, label_to_remove):
        for item in self.data:
            for annotation in item['annotations']:
                annotation['result'] = [
                    result for result in annotation['result'] 
                    if label_to_remove not in result['value']['labels']
                ]
        print(f"Label '{label_to_remove}' removed from all annotations.")

    def merge_labels(self, labels_to_merge, new_label):
        for item in self.data:
            for annotation in item['annotations']:
                for result in annotation['result']:
                    if result['value']['labels'][0] in labels_to_merge:
                        result['value']['labels'] = [new_label]
        print(f"Labels {labels_to_merge} merged into '{new_label}'.")

    def rename_labels(self, label_mapping):
        for item in self.data:
            for annotation in item['annotations']:
                for result in annotation['result']:
                    current_label = result['value']['labels'][0]
                    if current_label in label_mapping:
                        result['value']['labels'] = [label_mapping[current_label]]
        print(f"Labels renamed according to {label_mapping}.")

    def delete_annotations_with_label(self, label_to_delete):
        docs_affected = 0
        annotations_deleted = 0

        for item in self.data:
            original_annotation_count = len(item['annotations'])
            
            # Filter out annotations with the specified label
            for annotation in item['annotations'][:]:
                annotation['result'] = [
                    result for result in annotation['result'] 
                    if label_to_delete not in result['value']['labels']
                ]
                
                # If all results are removed, mark the annotation
                if not annotation['result']:
                    item['annotations'].remove(annotation)
                    annotations_deleted += 1

            # Check if any annotations were modified
            if len(item['annotations']) != original_annotation_count:
                docs_affected += 1

        print(f"Annotations with label '{label_to_delete}' have been deleted.")
        print(f"Number of documents affected: {docs_affected}")
        print(f"Number of annotations deleted: {annotations_deleted}")

    def save(self, output_file_path):
        try:
            with open(output_file_path, 'w', encoding='utf-8') as f:
                json.dump(self.data, f, ensure_ascii=False, indent=2)
            print(f"Conversion completed. Output saved to {output_file_path}")
        except Exception as e:
            raise Exception(f"Failed to save file: {str(e)}")

# %%
# Initialize the editor with the CoNLL file path
editor = LabelStudioEditor(r'c:\Users\Sakib Ahmed\Downloads\driving license_original.json')

# %%
# 1. View Annotations
editor.view_annotations()
# Out:
# Document Text: USA
# Florida
# DRIVER LICENSE
# 9CLASS E
# Ad DUN B123 - 456-78-910 - 0
# IJOHN
# 2DOE SAMPLE
# 81234 MAIN STREET LN
# JACKSONVILLE FL12345
# 3 DOB 01/01/1995 15SEX M
# 4b EXP 01/01/2026 16HGT 5 '- 10 "
# SAFE DRIVER
# 12 REOT NONE
# 9a END NONE
# 4aiss 01/01/2019
# SDD E123456123456
# - - L . aure ÃƒÂ
# Operation of a motor venicle constitutes
# consent to any sobriely test required by law
# Label: Country, Text: USA
# Label: State, Text: Florida
# Label: Address, Text: 81234 MAIN STREET LN
# JACKSONVILLE FL12345
# Label: Sex, Text: M
# Label: Height, Text: 5 '- 10 "
# Label: Restrictions, Text: NONE
# Label: Endorsement, Text: NONE
# Label: DD, Text: E123456123456
# Label: Class, Text: E
# Label: License_Number, Text: B123 - 456-78-910 - 0
# Label: Last_Name, Text: JOHN
# Label: First_Name, Text: DOE SAMPLE
# --------------------------------------------------
# Document Text: 50 - GTG
# DRIVER ' S LICENSE
# -
# 020133 DLI NO . 053274450 DOB 02/01/1995
# CLASS C
# EXP 02/01/2026
# IONNSTATE MIDDLE
# ADAMS
# HZROCKWELL DR
# LAGRANGE , GA 30240 - 9713 .
# TROUP
# Res trictions A
# iss 02/05/2018
# End NONE
# Loinstate Sex F .
# Eyos BLU
# Hgt 5 - 03 " Wgt 13516
# D0126223651130042825
# Idingtae
# Label: Document_Number, Text: 020133
# Label: License_Number, Text: 053274450
# Label: Class, Text: C
# Label: First_Name, Text: ADAMS
#
# Label: Endorsement, Text: NONE
# Label: Sex, Text: F
# Label: Eyes, Text: BLU
# Label: Height, Text: 5 - 03 "
# Label: Weight, Text: 13516
# Label: DD, Text: D0126223651130042825
# Label: Last_Name, Text: IONNSTATE MIDDLE
# Label: Address, Text: HZROCKWELL DR
# LAGRANGE , GA 30240 - 9713
# Label: Restrictions, Text: A
# --------------------------------------------------
# Document Text: DRIVER ' S
# LICENSE
# USA
# KS
# KANSAS
# 4d LIC . NO , K12-34-5678 48l ISS 01/11/2017
# 3 DOB 01/11/1966
# 46EXP 01/11/2023
# 1 SAMPLE
# 2 CARON ELIZABETH
# 8 123 NORTH STREET
# APT . 2
# TOPEKA , KS 66612 - 1234
# - CLASS A
# 9a END NONE
# 12 RES T NONE
# G
# 15SEX F
# 16 HGT 5 '- 06 "
# 17 WGT 140 lb
# 18 EYES BRO
# 01/11/66
# -
# ONONR Bamp -
# 5 : DD XX123XWMXX1
# 23XWMX123XWM12
# DONOR
# Label: DD, Text: USA
# Label: State, Text: KS
# Label: State, Text: KANSAS
# Label: Last_Name, Text: SAMPLE
# Label: Address, Text: 123 NORTH STREET
#
# Label: Address, Text: APT . 2
#
# Label: Address, Text: TOPEKA , KS 66612 - 1234
# Label: Class, Text: A
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: NONE
# Label: Sex, Text: F
# Label: Height, Text: 5 '- 06 "
# Label: Weight, Text: 140 lb
# Label: Eyes, Text: BRO
# Label: DD, Text: XX123XWMXX1
#
# Label: License_Number, Text: K12-34-5678 4
# Label: First_Name, Text: CARON ELIZABETH
# Label: Other, Text: DONOR
# Label: DD, Text: 23XWMX123XWM12
# --------------------------------------------------
# Document Text: USA
# - -
# - -
# 1
# PPI
# DRIVER LICENSE
# MISI SISSI
# 4d LICNO
# 123456789
# 3 DOB 01/12/1967
# 4b . EXP
# 01/12/2017
# 1 : SAMPLE
# 2 CONNOR M , JR
# 8 123 MAIN ST
# JACKSON , MS 39216 - 1234
# 4a ISS 01/10/2013
# 9 CLASS R 9a END ILPST 12 RES T BENQ
# 15 SEX M 16 HGT 5 '- 08 "
# 18 EYES BLU
# 5 DD 0123456789012345678901234
# Comansample ,
# Label: Country, Text: USA
# Label: License_Number, Text: 123456789
# Label: Last_Name, Text: SAMPLE
# Label: Class, Text: R
# Label: Restrictions, Text: BENQ
# Label: Sex, Text: M
# Label: Height, Text: 5 '- 08 "
# Label: Eyes, Text: BLU
# Label: DD, Text: 0123456789012345678901234
# Label: State, Text: MISI SISSI
# Label: First_Name, Text: CONNOR M , JR
# Label: Address, Text: 123 MAIN ST
# JACKSON , MS 39216 - 1234
# Label: Endorsement, Text: ILPST
# --------------------------------------------------
# Document Text: USAKY
# DRIVER ' S LICENSE
# UNBRIDLED
# Kentucky
# SPIRIT
# 090 - 0
# 4d Lic . No . S00 - 000 - 001
# - ÃƒÂ  - A
# 04-01-2014
# DL
# 4b Exp
# 3 DOB 04-01-1977 -
# www . kentucky . gov
# 1 SAMPLE
# 2 NICK
# 8 100 MAIN STREET
# APT . 1
# FRANKFORT , KY 40601 - 0000
# BRECKINRIDGE COUNTY
# Circuit Clerk
# harole - Lle
# 15 Sex M
# 16 Hgt 5 - 11
# -
# Yick Sample
# 12 Res trictions NONE
# 18 Eyes BRO 9 Class D
# 9a End P
# REV :
# 5DD S00000001DL10234 ORI CDL Res tr NONE 4a Iss 04-01-2010 03-16-2012
# Label: State, Text: Kentucky
# Label: License_Number, Text: S00 - 000 - 001
# Label: Last_Name, Text: 1 SAMP
# Label: First_Name, Text: 2 NI
# Label: Sex, Text: x
# Label: Height, Text: t 5 -
# Label: Restrictions, Text: s NO
# Label: Eyes, Text: s B
# Label: Class, Text: s
# Label: Endorsement, Text: d
# Label: DD, Text: D S00000001DL102
# Label: Restrictions, Text: r NO
# Label: Address, Text: 8 100 MAIN STREET
# APT . 1
# FRANKFORT , KY 40601 - 00
# --------------------------------------------------
# Document Text: Maine -
# DRIVER ' SLICENSE
# MOLNO . 1234567
# a - OPRES 01/12/2024 jooa 01/12/1967
# SAMPLE
# NICK
# - 123 STAYE STREET
# APT 1
# AUGUSTA , ME 04330 - 1234
# lassuto 06/26/2018 15CENDRM
# AKXK
# 5 - 06 "
# WDONT 19E
# 1851 B
# .
# BRO
# BLU
# CLASS A
# 2RES T NONE
# Saoo NONE
# CO 123456710012
# OONOA
# Label: License_Number, Text: 1234567
# Label: Last_Name, Text: SAMPLE
# Label: First_Name, Text: NICK
# Label: Hair, Text: BRO
# Label: Eyes, Text: BLU
# Label: Class, Text: A
# Label: Restrictions, Text: NONE
# Label: Restrictions, Text: NONE
# Label: DD, Text: 123456710012
# Label: State, Text: Maine
# Label: Address, Text: 123 STAYE STREET
# APT 1
# AUGUSTA , ME 04330 - 1234
# Label: Height, Text: 5 - 06 "
# Label: Weight, Text: 1851 B
# --------------------------------------------------
# Document Text: - - -
# A
# DRIVER ' S LICENSE
# ennsulvania
# Wg Acom DSA
# 4d - DLN : 27 . 546 026
# 31 DOB : 02/01/1995
# 4b EXP : 02/01/2022
# DUPS : 01
# 4a185 08/23/2018
# 1 ADAMS
# 21 IDINSTATE MIDDLE
# 8 . 707 E HILTON ST
# PHILADELPHIA , PA 19134
# 15SEX : F . 18EYES : BLU
# 16HGT 5 - 03 "
# CLASS : C .
# 9el END NONE
# 12RES TR : NONE
# DL
# SD0 : 182650003853
# 000000001033
# Idindtae
# Label: Last_Name, Text: ADAMS
# Label: First_Name, Text: IDINSTATE MIDDLE
# Label: Sex, Text: F
# Label: Eyes, Text: BLU
# Label: Class, Text: C
# Label: Endorsement, Text: NONE
# Label: Endorsement, Text: NONE
# Label: DD, Text: 182650003853
# Label: State, Text: ennsulvania
# Label: Height, Text: 5 - 03 "
# Label: Address, Text: 707 E HILTON ST
# PHILADELPHIA , PA 19134
# --------------------------------------------------
# Document Text: USA
# GA
# GEORGIA
# DL
# DRIVER ' S LICENSE
# Governor : Bih
# DRIVER ' S LICENSE
# 4d DL NO . 999999999 3 DOB 02/22/1983
# 9 CLASS CM
# 4b EXP 02/22/2028
# 2 IMA GEORGIA
# 1 SAMPLE
# 8 123 MAIN STREET
# ANYTOWN , GA 39999
# ANYCOUNTY
# 12 RES T NONE
# 9a END B
# 4a ISS
# 15 SEX M
# 16 HGT 6 '- 02 "
# 02/22/2018
# 18 EYES BLU
# 17 WGT 1951b
# 1e
# d Samy
# 02/22/1983
# 5 DD 12345678901234567890
# VETERAN
# Label: Country, Text: USA
# Label: State, Text: GEORGIA
# Label: License_Number, Text: 999999999
# Label: Last_Name, Text: IMA GEORGIA
# Label: First_Name, Text: SAMPLE
# Label: Address, Text: ANYCOUNTY
# Label: Restrictions, Text: NONE
# Label: Endorsement, Text: B
# Label: Sex, Text: M
# Label: Height, Text: 6 '- 02 "
# Label: Eyes, Text: BLU
# Label: Weight, Text: 1951b
# Label: DD, Text: 12345678901234567890
# Label: Other, Text: VETERAN
# Label: Class, Text: CM
# Label: Address, Text: 123 MAIN STREET
# ANYTOWN , GA 39999
# Label: State, Text: GA
# --------------------------------------------------
# Document Text: Real ID is indicated by a star in
# the upper right hand corner of a
# Driver ' s License , Permit , or ID
# s
# INDIANA
# OPERATOR LICENSE
# 023
# 4d D DLN 1234-56-7890
# 4e Iss 04/07/2015 9Exp 04/07/2021
# DONORS -
# - SAMPLE
# 2 AVERY
# 123 SAMPLE DRIVE
# APT . B
# INDIANAPOLIS , IN 46204 - 0000
# Class B
# 9a End NONE
# 12 Res BE
# 15Sex M
# 16Hgt 5 - 08 " -
# 171 Wgt 165 ib
# 181 Eyes BRO
# Owoy . Somple 3 DO8 04/07/1986
# Transaction 04070602300001 19 Hair BRO
# Label: State, Text: INDIANA
# Label: Other, Text: DONORS
# Label: Last_Name, Text: SAMPLE
# Label: First_Name, Text: AVERY
# Label: Class, Text: B
# Label: Endorsement, Text: NONE
# Label: Sex, Text: M
# Label: Height, Text: 5 - 08 "
# Label: Eyes, Text: BRO
# Label: DD, Text: 04070602300001
# Label: Hair, Text: BRO
# Label: License_Number, Text: 1234-56-7890
# Label: Address, Text: 123 SAMPLE DRIVE
# APT . B
# INDIANAPOLIS , IN 46204 - 0000
# Label: Restrictions, Text: BE
# Label: Weight, Text: 165 ib
# --------------------------------------------------
# Document Text: USA
# TX
# -
# Texas
# DRIVER LICENSE - -
# 4d DL 16564745
# 9 Class C
# 4a Iss 04/06/2017
# 4b Exp 04/20/2024
# 3 DOB 04/20/1995
# 1 FAKES
# 2 DINGO
# 8 15820 CROWLEY RD
# CONROE TX 77306 - 6952
# 12 Res trictions NONE
# Da End NONE
# 16 Hgt 5 - 07
# 15 Sex
# =
# Lors
# M 18 Eyes BLK
# Fakes
# 5 DD 09110601361122354773
# Label: Country, Text: USA
# Label: State, Text: TX
# Label: State, Text: Texas
# Label: License_Number, Text: 16564745
# Label: Class, Text: C
# Label: Address, Text: 15820 CROWLEY RD
#
# Label: Address, Text: CONROE TX 77306 - 6952
# Label: Restrictions, Text: NONE
# Label: Endorsement, Text: NONE
# Label: Height, Text: 5 - 07
# Label: Sex, Text: M
# Label: Eyes, Text: BLK
# Label: DD, Text: 09110601361122354773
# Label: Last_Name, Text: FAKES
# Label: First_Name, Text: DINGO
# --------------------------------------------------
# Document Text: Rhode Island
# DRIVER LICENSE
# USA
# 3 DOB 01/16/1964
# 461 EXP 01/16/2021
# 4d LIC # V007989
# 4a136 07/18/2016
# 1SAMPLE
# 21AM
# EDDD
# 8 600 NEW LONDON AVE
# CRANSTON , RI 02920
# 9 CLASS 10
# 9al END NONE
# 121 RES TR NONE
# 15SEX M
# 01/16/1964
# 18EYES BLU
# o
# 16HGT 5 - 10 " 17WGT 150 Ib 19HAIR UNK
# - -
# 5 CD V00798920121127033338
# Om Samale
# VETERAN
# Label: State, Text: Rhode Island
# Label: Country, Text: USA
# Label: License_Number, Text: V007989
# Label: Class, Text: 10
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: NONE
# Label: Sex, Text: M
# Label: Eyes, Text: BLU
# Label: Weight, Text: 150
# Label: Hair, Text: UNK
# Label: DD, Text: V00798920121127033338
# Label: Other, Text: VETERAN
# Label: Last_Name, Text: SAMPLE
# Label: First_Name, Text: 1AM
# Label: Address, Text: 600 NEW LONDON AVE
# CRANSTON , RI 02920
# Label: Height, Text: 5 - 10 "
# --------------------------------------------------
# Document Text: MISSOURI
# 1L API Lh
# DRIVER LICENSE
# 9CLASS F
# 4b EXW 06/04/2024
# 4d DL NO H521826320 3008 06/04/1975
# 1JOLIE
# ZANGELINA
# 84846 WRIGTHWOODAVE
# KANSAS CITY , MO 64146
# 9a END NONE
# 12 RES TRICTIONS NONE
# 18 HGT 5 - 07 " 1a EYES BLU
# 151 SEX F
# WGT 130 lb 4a1ss 05/21/201
# angelora folie
# SDD 651201172291
# Label: State, Text: MISSOURI
# Label: Class, Text: F
# Label: License_Number, Text: H521826320
# Label: First_Name, Text: ZANGELINA
# Label: Address, Text: 84846 WRIGTHWOODAVE
# KANSAS CITY , MO 64146
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: NONE
# Label: Height, Text: 5 - 07 "
# Label: Eyes, Text: BLU
# Label: Sex, Text: F
# Label: Weight, Text: 130 lb
# Label: DD, Text: 651201172291
# Label: Last_Name, Text: JOLIE
# --------------------------------------------------
# Document Text: Federal
# California USA DRIVER LICENSE
# Compliant
# DL11234568
# CLASS C
# EXP 08/31/2014
# LNCARDHOLDER
# FNIMA
# END NONE
# 2570 24TH STREET
# ANYTOWN , CA 95918
# DOB 08/31/1977
# RSTRNONE
# 08311977
# VETERAN
# SEX F
# C
# HAIR BRN EYES
# -
# Iua
# Coulheldcu
# BRN
# ISS
# 08/31/2009
# HGT 5 - 05 " WGT 1251 ib
# DD 0000NMMANANFOYY
# Label: State, Text: California
# Label: Country, Text: USA
# Label: License_Number, Text: DL11234568
# Label: Class, Text: C
# Label: Last_Name, Text: LNCARDHOLDER
# Label: First_Name, Text: FNIMA
# Label: Endorsement, Text: NONE
# Label: Other, Text: VETERAN
# Label: Sex, Text: F
# Label: Class, Text: C
# Label: Hair, Text: BRN
# Label: Eyes, Text: BRN
# Label: DD, Text: 0000NMMANANFOYY
# Label: Address, Text: 2570 24TH STREET
# ANYTOWN , CA 95918
# Label: Restrictions, Text: NONE
# Label: Document_Number, Text: 08311977
# Label: Weight, Text: 1251 ib
# Label: Height, Text: 5 - 05 "
# --------------------------------------------------
# Document Text: USA
# TX
# -
# exas
# DRIVER LICENSE
# 4d DL 39175097
# % Class C
# 4a Iss 12/05/2019
# 4b Exp 12/12/2024
# 3 DOB 12/12/1989
# LLAST NAME
# 2 FIRST NAME
# 8 123 FAKETEMPLATE . COM
# PLANO TX . 75074
# X
# 12 Res trictions NONE
# 9a End NONE
# 16 Hgt 6 - 09 Tempsexe IVS 18 Eyes BRO DONOR
# pltaplt
# 5 DD 00596875402103051482
# ale
# Label: Country, Text: USA
# Label: State, Text: TX
# Label: License_Number, Text: 39175097
# Label: Class, Text: C
# Label: Address, Text: 123 FAKETEMPLATE . COM
#
# Label: Restrictions, Text: NONE
# Label: Endorsement, Text: NONE
# Label: Height, Text: 6 - 09
# Label: Eyes, Text: BRO
# Label: Other, Text: DONOR
# Label: DD, Text: 00596875402103051482
# Label: Last_Name, Text: LAST NAME
# Label: First_Name, Text: FIRST NAME
# Label: Address, Text: PLANO TX . 75074
# --------------------------------------------------
# Document Text: MICHIGAN :
# DRIVER LICENSE
# D616067 108 334
# 008 05-01-1978
# ISS 05-01-2014
# EXP , 05-01-2018 06014
# ANNE CARR DRIVER
# 123 NORTH STATE ST ,
# LANSING , MI : 48918 - 0000
# Sex F
# Hgr 504
# Eyes BRO
# Lic Type 0
# End NONE
# Res trictions . NONE
# Inni Con A - 4
# OONOR -
# Revmmn
# DD 0130002496719
# Veteran
# Label: State, Text: MICHIGAN
# Label: License_Number, Text: D616067 108 334
# Label: Sex, Text: F
# Label: Eyes, Text: BRO
# Label: License_Type, Text: 0
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: NONE
# Label: Other, Text: OONOR
# Label: DD, Text: 0130002496719
# Label: Last_Name, Text: ANNE
# Label: First_Name, Text: CARR DRIVER
# Label: Address, Text: 123 NORTH STATE ST ,
# LANSING , MI : 48918 - 0000
# Label: Other, Text: Veteran
# Label: Document_Number, Text: 06014
# --------------------------------------------------
# Document Text: USA
# IOWA
# LIMITED - TERM
# DRIVER LICENSE
# SAMPLE
# 2MARK
# - -
# de
# 8123 NORTH STREET
# APT 201
# DES MOINES , IA 50301 - 1234
# DLNO . 123XX6789
# -
# 4alss 11/07/2016 4b ! Exp 01/12/2021
# Di5Sex M 16Hgt 5 '- 08 " 18Eyes BRO
# 9 Class C 9al End NONE
# 12Res t NONE
# - DONOR
# MED ALERT X
# HEARING IMP : Y
# ADV DIR :
# VETERAN MED
# Y
# -
# - C - - - - - - a - - - - -
# -
# 3DOB 01/12/1967
# 01/12/67
# 5DD 12345678901234567890123D
# Moak . sompl
# Label: Country, Text: USA
# Label: State, Text: IOWA
# Label: Last_Name, Text: SAMPLE
# Label: Address, Text: 8123 NORTH STREET
#
# Label: Address, Text: APT 201
#
# Label: Address, Text: DES MOINES , IA 50301 - 1234
# Label: License_Number, Text: 123XX6789
# Label: Sex, Text: M
# Label: Height, Text: 5 '- 08 "
# Label: Eyes, Text: BRO
# Label: Class, Text: C
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: NONE
# Label: Other, Text: DONOR
# Label: Other, Text: VETERAN
# Label: First_Name, Text: MARK
# Label: Other, Text: MED ALERT
# Label: DD, Text: 12345678901234567890123D
# Label: Other, Text: MED
# --------------------------------------------------
# Document Text: USA
# IN
# ÃƒÂ
# DRIVER LICENSE
# Ln
# Lennerree -
# THEVOLUNTEER STATE
# DL NO 549121907 DOB 11/13/1995
# EXP 11/13/2021
# iss1 12/15/2044
# CLASS D
# RES T 1
# END NONE
# SEX M HGT 6 '- 01 " EYES BRN
# DD 5314027690403437
# DL
# A
# STEVEN
# JACK TILSON
# WWW . USATEMPLATE . XYZ
# KNOXVILLE , TN 37912
# Ps Download Ps D Templates . com
# Label: Country, Text: USA
# Label: License_Number, Text: O 5491219
# Label: Class, Text: S
# Label: Endorsement, Text: D NO
# Label: Sex, Text: X
# Label: Height, Text: T 6 '- 01
# Label: Eyes, Text: S B
# Label: DD, Text: D 53140276904034
# Label: Restrictions, Text: T
# Label: State, Text: n
# Lennerr
# Label: Last_Name, Text: A
# STEV
# Label: First_Name, Text: N
# JACK TILS
# Label: Address, Text: N
# WWW . USATEMPLATE . XYZ
# KNOXVILLE , TN 379
# --------------------------------------------------
# Document Text: MINNESOTA
# Af AA SEGWAYDRIVER ' S LICENSE
# TAMMY LEE
# 616 Crazy Drive
# Montgomery , MN 55359
# Date of Birth 10-07-1968 .
# Sex
# F
# Eyes
# BRO
# Class
# C
# Height Weight
# 504
# 136 DONOR
# ISSUED 10-10-2010 EXP IRES 10-10-2020
# Lee
# STATUS CHECK
# 10 - 0T - 2007
# C - 123 - 456 - 789 - 321
# Tammy
# Label: State, Text: MINNESOTA
# Label: Address, Text: 616 Crazy Drive
# Montgomery , MN 55359
# Label: Eyes, Text: BRO
# Label: Class, Text: C
# Label: Other, Text: DONOR
# Label: Last_Name, Text: Tammy
# Label: First_Name, Text: LEE
# Label: Last_Name, Text: TAMMY
# Label: Height, Text: 504
# Label: License_Number, Text: C - 123 - 456 - 789 - 321
# Label: Sex, Text: F
# --------------------------------------------------
# Document Text: OSA
# DE
# DELAWARE -
# TIE HRST STATL
# Ad DLE No . 4817502
# DRIVER LICENSE
# a Class D
# 42 Iss 02-02-2016
# 401 Exp 01-01-2021
# - IDTOP
# 2 RICKY ALLEN
# - 26 TALLADEGA ST
# NEWARK , DE 19716 - 2505
# 95
# Wat - Eyos
# a DOB
# a
# 6 - 037 250 lb BRO
# 01-01-1995
# Rostrictions
# NONE
# IDTOP
# End NONE
# A Cohar
# ORECTOR
# Label: State, Text: DE
#
# Label: State, Text: DELAWARE
# Label: License_Number, Text: 4817502
# Label: Class, Text: D
# Label: Last_Name, Text: IDTOP
# Label: Height, Text: 6 - 037
# Label: Weight, Text: 250 lb
# Label: Eyes, Text: BRO
# Label: Restrictions, Text: NONE
# Label: Endorsement, Text: NONE
# Label: First_Name, Text: RICKY ALLEN
# Label: Address, Text: 26 TALLADEGA ST
# NEWARK , DE 19716 - 2505
# --------------------------------------------------
# Document Text: NEW YORK STATE
# US
# DRIVER LICENSE
# ÃƒÂ
# 4123 456 789
# MOTORIST
# MICHAEL , MATTHEW
# 2345 ANYWHERE STREET
# YOUR CITY , NY 12345
# Can D
# Sex M Heght 5 '- 08 " Eyes BRO
# coe 08/31/1982
# Exp ires 10/30/2025
# NONE
# 3 NONE
# lusued 10/30/2017
# MICHAS
# A -
# SAMPLE
# AUG
# Label: State, Text: NEW YORK STATE
# Label: License_Number, Text:
# 4123 456 7
# Label: Last_Name, Text: 9
# MOTORI
# Label: First_Name, Text: T
# MICHAEL , MATTH
# Label: Address, Text: W
# 2345 ANYWHERE STREET
# YOUR CITY , NY 123
# Label: Class, Text: n
# Label: Sex, Text: x
# Label: Height, Text: t 5 '- 08
# Label: Eyes, Text: s B
# Label: Endorsement, Text: 5
# NO
# Label: Restrictions, Text: 3 NO
# --------------------------------------------------
# Document Text: DNM CALIFORNIA DAE
# DRIVERS LICENSE
# 10263905
# MAXTIN MCFLY
# 1303 LYON ORIVE
# HILL VALLET CA 15420
# SEX : n MAIRI BRN LYEST BLU
# HT SOS - 04 UT : 145
# ( LASSIC
# XPIRES ab - 01 - 47
# 0
# Mantiny . Mefly
# 06/09/1958 00 11 051855
# Label: State, Text: CALIFORNIA
# Label: License_Number, Text: 10263905
# Label: First_Name, Text: MAXTIN MCFLY
#
# Label: Address, Text: 1303 LYON ORIVE
# HILL VALLET CA 15420
# Label: Hair, Text: BRN
# Label: Eyes, Text: BLU
# Label: Weight, Text: 145
# Label: DD, Text: 051855
# --------------------------------------------------
# Document Text: NEW YORK STATE
# - -
# DRIVER LICENSE
# Gubae .
# ID 123 456789
# Class U
# MOTORIST
# MICHAEL , M
# SAMPLE
# 2345 ANYWHERE STREET
# YOUR CITY , NY 12345
# Sex M Height 5 '- 09 " Eyes BLU
# DOB 08/31/1978
# Exp ires 08/31/2021
# -
# -
# E NONE
# -
# R NONE
# HAEL
# hael - Motonist
# AUG 78
# Issued 08/31/2013
# Organ Donor ABC3456789
# Label: State, Text: NEW YORK STATE
# Label: License_Number, Text: 123 456789
#
# Label: Class, Text: U
# Label: Last_Name, Text: MOTORIST
# Label: First_Name, Text: MICHAEL , M
# Label: Sex, Text: M
# Label: Height, Text: 5 '- 09 "
# Label: Eyes, Text: BLU
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: NONE
# Label: Address, Text: 2345 ANYWHERE STREET
# YOUR CITY , NY 12345
# Label: Document_Number, Text: ABC3456789
# Label: Other, Text: Organ Donor
# --------------------------------------------------
# Document Text: DRIVER ' S
# LICENSE
# USA
# KS
# KANSAS
# 4GLICNO . K01-75-4269 fa ISS 10/21/2013
# - 1i00B 04/23/1962
# 4b1 EXP 04/23/2019
# SAMPLE
# 2 : TEST ONE
# 8 RR 2
# HOLTON , KS 66436
# CLASS AM
# 9a END NONE
# 12 RES T WBJ
# 15 SEX M
# 16 HGT 5 - 10 "
# 17 ) WGT 180 Ib 04/23/62
# Janice fample 18 EYES BLU
# 5 DD 62941433152
# ST17165M1923DB
# DONOR
# IDRIVER LICENSE NUMBER
# ME
# BISSUE DATE
# - EXP IRATION DATE
# Label: Country, Text: USA
# Label: Last_Name, Text: SAMPLE
# Label: Sex, Text: M
# Label: Height, Text: 5 - 10 "
# Label: Weight, Text: 180
# Label: Eyes, Text: BLU
# Label: DD, Text: 62941433152
# Label: Other, Text: DONOR
# Label: State, Text: KANSAS
# Label: License_Number, Text: K01-75-4269
# Label: First_Name, Text: TEST ONE
# Label: Address, Text: RR 2
# HOLTON , KS 66436
# Label: Class, Text: AM
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: WBJ
# Label: DD, Text: ST17165M1923DB
# Label: State, Text: KS
# --------------------------------------------------
# Document Text: JULINQIS a
# Jesse White - Secretary of State ?
# NOT VALID FOR
# DDENTIFICATION
# TVDL
# Cic . No . T134 - 7835 - 5001
# DOB :
# 01-01-75
# Cless : D
# End :
# Res t :
# Type : ORG
# Expires i 04-10-15
# Issued : 04-10-12
# SAMPLE CARD HVDL
# 1234SAMPLE ST
# ANY TOWN IL 60640
# Spph -
# T Vo L
# Female s H " 110 ibs HZL Eyes
# Label: State, Text: JULINQIS
# Label: License_Number, Text: T134 - 7835 - 5001
# Label: Last_Name, Text: SAMPLE
# Label: Weight, Text: 110
# Label: First_Name, Text: CARD HVDL
# Label: Address, Text: 1234SAMPLE ST
# ANY TOWN IL 60640
# Label: Sex, Text: Female
# Label: Eyes, Text: HZL
# Label: Class, Text: D
# Label: License_Type, Text: ORG
# --------------------------------------------------
# Document Text: DRIVER LICENSE
# USA
# Aizona
# 9 CLASS D
# 9a END NONE
# 12 RES T NONE
# 1 JOLIE
# 2 ANGELINA
# B58471293
# 4d DLN
# d DOB 06/04/1975
# 8 6829 E CHEERY LYNN RD
# SURPRISE , AZ 85388 - 5248
# 4b EXP 06/04/2040 4a ISS 06/01/2017
# 15 SEX F
# 18 EYES BLU
# 16 HGT 5 '- 07 " 19 HAIR BRO
# 17 WGT 130 Ib
# 06/04/75
# angelina golie
# 5 DD 1356C1390A0816CO
# Label: Country, Text: USA
# Label: Class, Text: D
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: NONE
# Label: Last_Name, Text: JOLIE
# Label: First_Name, Text: ANGELINA
# Label: License_Number, Text: B58471293
# Label: Address, Text: 6829 E CHEERY LYNN RD
# SURPRISE , AZ 85388 - 5248
# Label: Sex, Text: F
# Label: Eyes, Text: BLU
# Label: Height, Text: 5 '- 07 "
# Label: Hair, Text: BRO
# Label: Weight, Text: 130 Ib
# Label: DD, Text: 1356C1390A0816CO
# Label: State, Text: Aizona
# --------------------------------------------------
# Document Text: NEW YORK STATE
# USA
# DRIVER LICENSE
# -
# 4
# ID 3376 656 725
# CATHERINE
# ANN , S
# Class D
# 40 EAST 67TH STREET
# NEWYORK , NY 10065
# Sex Fa Height 5 '- 05 " Eyes BRO
# 008 02/01/1995
# Exp ires 02/01/2024
# E NONE
# R NONE
# -
# EXCELSIOR
# issued 11/01/2016
# Label: State, Text: NEW YORK STATE
# Label: Country, Text: USA
# Label: License_Number, Text: 3376 656 725
# Label: First_Name, Text: ANN , S
#
# Label: Class, Text: D
# Label: Eyes, Text: BRO
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: NONE
# Label: Last_Name, Text: CATHERINE
# Label: Address, Text: 40 EAST 67TH STREET
# NEWYORK , NY 10065
# Label: Height, Text: 5 '- 05 "
# --------------------------------------------------
# Document Text: Texass
# DRIVER LICENSE
# Director :
# DRIVER LICENSE
# 4d . DL : 10003422
# 9 . Class : M
# 4b . Exp : 03/06/2023
# 3 . DOB : 08/12/1983 4a . Iss : 03/06/2017
# 1 . SAMPLE
# 2JOAN
# 8 . 1 12 COTTONWOOD RD
# EAST TEXAS CENTER , TX 12345 - 0000
# 12 . Res t : FP
# 9a . End : HX
# 16 . Hgt : 7 '- 01 " 16 . Sex F 18 . Eyes : MAR
# 5 . DO : 00000000000000070
# > -
# COMMUNICATION IMPEDIMENT
# Label: License_Number, Text: 10003422
# Label: Class, Text: M
# Label: Last_Name, Text: SAMPLE
# Label: Restrictions, Text: FP
# Label: Sex, Text: F
# Label: Eyes, Text: MAR
# Label: DD, Text: 00000000000000070
# Label: State, Text: Texass
# Label: First_Name, Text: JOAN
# Label: Address, Text: 12 COTTONWOOD RD
# EAST TEXAS CENTER , TX 12345 - 0000
# Label: Endorsement, Text: HX
# Label: Height, Text: 7 '- 01 "
# --------------------------------------------------
# Document Text: - o
# VA , USA
# Virginia DRIVER ' S LICENSE
# Cautemer Hratifier
# T16700185
# Name
# MURRY
# JUSTIN WILLIAM
# Cean Cedr
# ABCF
# Addreas
# 123 EXAMPLE CARD ONLY
# NOT VALID , VA 12345
# Sex
# M
# Hye
# BRO
# Heigkt
# Class
# NONE
# Date binth
# 07/15/1958
# -
# MCAOS
# Endensements lar ORI
# ÃƒÂ  - - - in
# Organt Doner
# DD 123456789
# S
# Res trictiens
# 08/14/2014
# Exp
# 08/14/2019
# -
# 6FT3IN 1 , 5 , 8 , X , 9
# Label: Country, Text: USA
# Label: State, Text: Virginia
# Label: License_Number, Text: T16700185
# Label: Last_Name, Text: MURRY
# Label: First_Name, Text: JUSTIN WILLIAM
# Label: Sex, Text: M
# Label: Eyes, Text: BRO
# Label: Class, Text: NONE
# Label: DD, Text: D 1234567
# Label: Height, Text: -
# 6FT3
# Label: Address, Text: 123 EXAMPLE CARD ONLY
# NOT VALID , VA 12345
# --------------------------------------------------
# Document Text: KANSAS
# DRIVER ' S
# LICENSE
# USA
# KS
# 3 DOB 06/11/1978
# IDVIKING . COM
# 21 THOR THUNDER
# 8 69 BIG HAMMER WAY
# COFFEYVILLE KS , 12345
# Ad LIC , NO K03-66-2278
# 4a Is S 08/05/2019
# 4b1 EXP 06/11/2027
# 93 DL CLASS C
# CDL CLASS
# 9a END NONE
# 12 RES T NONE
# 53 DD 61234567896
# SC12345F1615AB
# 15 : SEX M
# 16 HGT 6 '- 04 "
# 17 WGT 170 Ib
# 18 EYES BLU
# Thor Odison
# ORGAN DONOR
# -
# Label: State, Text: KANSAS
# Label: Country, Text: USA
# Label: Class, Text: C
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: NONE
# Label: Sex, Text: M
# Label: Height, Text: 6 '- 04 "
# Label: Eyes, Text: BLU
# Label: Other, Text: ORGAN DONOR
# Label: Last_Name, Text: IDVIKING . COM
# Label: First_Name, Text: THOR THUNDER
# Label: Address, Text: 69 BIG HAMMER WAY
# COFFEYVILLE KS , 12345
# Label: License_Number, Text: K03-66-2278
# Label: Weight, Text: 170 Ib
# Label: DD, Text: 61234567896
# SC12345F1615AB
# --------------------------------------------------
# Document Text: :
# d
# - a - FAFEFEER
# Ahizomn
# DRIVER LICENSE
# USA
# 9 CLASS D
# 9a END NONE
# 12 RES T NONE
# 1 SAMPLE
# 2 JELANI
# 4d DLN D12345678
# 3 DOB 02/01/1957
# 8 123 MAIN STREET
# PHOENIX , AZ 85007
# 4b EXP 02/01/2018 4a ISS 01/10/2013
# 15 a SEX M
# 18 EYES BRO VETERAN
# 16 HGT 5 - 08 " 19 HAIR BRO
# 17 WGT 185 lb
# DONOR
# 5DD
# 02/01/57
# Selamis
# 1234567890123456
# Sample
# Label: License_Number, Text: USA
# Label: Class, Text: D
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: NONE
# Label: Last_Name, Text: SAMPLE
# Label: First_Name, Text: JELANI
# Label: License_Number, Text: D12345678
# Label: Address, Text: 123 MAIN STREET
# PHOENIX , AZ 85007
# Label: Sex, Text: M
# Label: Eyes, Text: BRO
# Label: Other, Text: VETERAN
# Label: Height, Text: 5 - 08 "
# Label: Hair, Text: BRO
# Label: Weight, Text: 185 lb
# Label: Other, Text: DONOR
# Label: DD, Text: 1234567890123456
# --------------------------------------------------
# Document Text: ILLINOIS
# Jesse White * Secretary of State
# DRIVER ' S LICENSE
# USA
# 4d LIC No . P142 - 4558 - 7924
# 3 DO8 : 11/14/1987
# 4b EXP : 11/14/2020
# 4a ISS : 05/01/2016
# 1 PUBLIC
# 2JANE Q
# 8 1234 MAIN STREET
# SPRINGFIELD , IL 62723
# 9 CLASS : D
# 12RES T NONE
# 9a END : NONE
# 15SEX : F
# 16HGT 5 '- 6 "
# 17WGT : 145 Ibs 18EYES : BRN TYPE : ORG
# 20160210993DT0326
# pma Qlible
# 5DD
# Label: State, Text: ILLINOIS
# Label: License_Number, Text: P142 - 4558 - 7924
# Label: Last_Name, Text: PUBLIC
# Label: Class, Text: D
# Label: Restrictions, Text: NONE
# Label: Endorsement, Text: NONE
# Label: Sex, Text: F
# Label: Height, Text: 5 '- 6 "
# Label: Weight, Text: 145 Ibs
# Label: Eyes, Text: BRN
# Label: DD, Text: 20160210993DT0326
# Label: First_Name, Text: JANE Q
# Label: Address, Text: 1234 MAIN STREET
# SPRINGFIELD , IL 62723
# --------------------------------------------------
# Document Text: USA
# TX
# DRIVER LICENSE
# Texas
# Soante
# 4a DL 07526390
# 4a Iss 04/14/2015
# 3 DOB 12/11/1977
# Class B
# 4b Exp 12/11/2019
# MICHAEL
# 2 KAMARA
# 2544 LA CASTA DR
# AUSTIN , TX 78704
# 12 Res trictions A
# 16 Hgt 6 - 00
# Sa End PS
# 15 Sex M 18 Eyes BI
# 5 DD 27510520146146104809728
# Label: Country, Text: USA
# Label: State, Text: Texas
# Label: License_Number, Text: 07526390
# Label: Class, Text: B
# Label: Last_Name, Text: MICHAEL
# Label: First_Name, Text: KAMARA
# Label: Height, Text: 6 - 00
# Label: Endorsement, Text: PS
# Label: Sex, Text: M
# Label: DD, Text: 27510520146146104809728
# Label: Address, Text: 2544 LA CASTA DR
# AUSTIN , TX 78704
# Label: Restrictions, Text: A
# Label: Eyes, Text: BI
# Label: State, Text: TX
# --------------------------------------------------
# Document Text: NORTH SA
# DRIVER LICENSE
# Bru
# CAMESTROEGICRVEIEL
# 4d DLN 300031699905
# ADOB 12/25/1968
# DER 12/25/2025
# 1 DOE
# 2 TRENA
# 8 421 UATBLVD
# RALEIGHNC 27697 - 0001
# 1 SS C
# RES TR 1
# 15SEX F
# 9BEND NONE
# 18EYES BRO
# 16HGT 5 '- 05 " 19HAIR BLK RACE B
# June Doe
# 4a . TSS 02/20/2017
# 5 . DD . 3001809397
# 12/25/68
# Label: State, Text: NORTH SA
# Label: License_Number, Text: 300031699905
# Label: Last_Name, Text: DOE
# Label: Sex, Text: C
# Label: Sex, Text: F
# Label: Endorsement, Text: NONE
# Label: Eyes, Text: BRO
# Label: Hair, Text: BLK
# Label: DD, Text: 3001809397
# Label: First_Name, Text: TRENA
# Label: Address, Text: 421 UATBLVD
# RALEIGHNC 27697 - 0001
# Label: Height, Text: 5 '- 05 "
# Label: Race, Text: B
# Label: Restrictions, Text: 1
# --------------------------------------------------
# Document Text: WASHINGTON ENHANCED DRIVER LICENSE
# LIC # RAMIRJM302JA
# EXP 04-01-2010
# RAMIREZ , JENNIFER MARIE
# 123 MAIN STREET
# ROYAL CITY WA 99499
# CDL
# SEX
# F
# END
# HT
# 5 - 04
# RES
# WT
# 110
# EYES
# BRN
# ISSUE DATE 01-26-2006
# DOB 04-01-1970
# Genife -
# Raniny
# Label: State, Text: WASHINGTON
# Label: Address, Text: 123 MAIN STREET
# ROYAL CITY WA 99499
# Label: Sex, Text: F
# Label: Height, Text: 5 - 04
# Label: Weight, Text: 110
# Label: Eyes, Text: BRN
# Label: License_Number, Text: RAMIRJM302JA
# Label: First_Name, Text: JENNIFER MARIE
# Label: Last_Name, Text: RAMIREZ
# --------------------------------------------------
# Document Text: USA
# GA
# GEORGIA
# DRIVERS LICENSE
# Govemori EPR
# DL
# DRIVER ' S LICENSE
# MON0123456789
# CLASS C
# 000 06/01/1984
# 6 X 05/25/2023
# IMA GEORGIA
# SAMPLE
# 2206 EASTVIEW PARKWAY
# CONYERS , GA 30013 - 5755
# ROCKDALE
# 12 RES TR A
# 2a END NONE
# a ss 05/25/2018
# 155EX F
# 1EYES BRO
# 00/01/1904
# Signatue - -
# 16 HGT 5 - 08 " 171 WGY 155 lb
# 00 12345678901234667890
# ORGAN DONOR
# Label: Country, Text: USA
# Label: State, Text: GA
# Label: State, Text: GEORGIA
# Label: License_Number, Text: MON0123456789
# Label: Class, Text: C
# Label: Address, Text: 2206 EASTVIEW PARKWAY
#
# Label: Address, Text: CONYERS , GA 30013 - 5755
# Label: Restrictions, Text: A
# Label: Endorsement, Text: NONE
# Label: Sex, Text: F
# Label: Eyes, Text: BRO
# Label: Height, Text: 5 - 08 "
# Label: Weight, Text: 171
# Label: Weight, Text: 155 lb
# Label: DD, Text: 12345678901234667890
# Label: Other, Text: ORGAN
# Label: Other, Text: DONOR
# Label: Last_Name, Text: IMA GEORGIA
# Label: First_Name, Text: SAMPLE
# Label: Address, Text: ROCKDALE
# --------------------------------------------------
# Document Text: SSOURI
# Class
# -
# DRIVER LICENSE
# License Number M901259010
# DOE
# JOHN
# 100 MAIN STREET
# Kthon
# ANYWHERE , MO 60000
# Birthdate
# 03-05-1955
# Exp iration Date
# 03-05-2009
# Male
# 5 ' 10 165 Ibs Brown Eyes
# Res trictions
# Endorsements
# IA
# Doe
# Label: State, Text: SSOURI
# Label: License_Number, Text: M901259010
# Label: Last_Name, Text: DOE
# Label: First_Name, Text: JOHN
#
# Label: Address, Text: 100 MAIN STREET
#
# Label: Height, Text: 5 ' 10
# Label: Weight, Text: 165
# Label: Address, Text: ANYWHERE , MO 60000
# Label: Eyes, Text: Brown
# --------------------------------------------------
# Document Text: DRIVER LICENSE
# ALABAMA
# NO . 1 1845133
# CLASS D
# D . 0 . 8 . 06-04-1969 EXP 06-04-2019
# NELSON
# MANDELA
# 56 PEACE AVE
# JACKSON AL 36545
# ENDORSEMENTS
# ISS 07-13-2014
# RES T
# SEX M HT 610 gves ! BRO
# WT 185 HARBRO
# - a
# Colonel John E . Richardson
# Director of Publie Safety
# Ne dsom Mandala
# Label: State, Text: ALABAMA
# Label: Class, Text: D
# Label: Last_Name, Text: NELSON
# Label: First_Name, Text: MANDELA
# Label: Sex, Text: M
# Label: Height, Text: 610
# Label: Eyes, Text: BRO
# Label: Weight, Text: 185
# Label: Address, Text: 56 PEACE AVE
# JACKSON AL 36545
# Label: Hair, Text: BRO
# Label: License_Number, Text: 1845133
# --------------------------------------------------
# Document Text: NEW YORK STATE
# USA
# DRIVE R . LICENSE
# ID 911 161 - - 108
# Class )
# ROSSETTI
# DAWN M
# 116 CATERINE AVE
# FRANKLIN SQUARE , NY 11010
# Sex M Height 5 '- 06 " Eyes BLU
# DOB 04/07/1973
# Exp ires 04/07/2020
# - - - VA >
# E NONE
# R NONE
# Suy Somple
# EXCELSIOR
# ÃƒÂ  R7 : -
# issued 08/23/2017
# 29KEW430167
# Label: State, Text: NEW YORK STATE
# Label: Country, Text: USA
# Label: Sex, Text: M
# Label: Height, Text: 5 '- 06 "
# Label: Eyes, Text: BLU
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: NONE
# Label: DD, Text: 7
# 29KEW4301
# Label: License_Number, Text: 911 161 - - 108
# Label: Last_Name, Text: ROSSETTI
# Label: First_Name, Text: DAWN M
# Label: Address, Text: 116 CATERINE AVE
# FRANKLIN SQUARE , NY 11010
# --------------------------------------------------
# Document Text: California USA
# DRIVER LICENSE
# FEDERAL
# LIMITS
# APPLY
# DL11234562
# CLASS C
# EXP 08/31/2014
# END NONE
# E LNSAMPLE
# FNALEXANDER JOSEPH
# 2570 24TH STREET
# ANYTOWN , CA 95818
# DOB 08/31/1977
# RSTRNONE
# 08311977
# DONOR
# 4
# SEX M
# HAIR BLK
# EYES BRN
# Culex
# ar - -
# HGT 5 - 08 " WGT 150 lb
# DD 00/00/0000NNNANIANFD/YY
# ISS
# 08/31/2009
# Label: State, Text: California
# Label: Country, Text: USA
# Label: License_Number, Text: DL11234562
# Label: Class, Text: C
# Label: Endorsement, Text: NONE
# Label: First_Name, Text: JOSEPH
# Label: Address, Text: 2570 24TH STREET
#
# Label: Document_Number, Text: 08311977
# Label: Other, Text: DONOR
# Label: Sex, Text: M
# Label: Hair, Text: BLK
# Label: Eyes, Text: BRN
# Label: Height, Text: 5 - 08 "
# Label: Weight, Text: 150 lb
# Label: DD, Text: 00/00/0000NNNANIANFD/YY
# Label: First_Name, Text: ALEXANDER
# Label: Last_Name, Text: SAMPLE
# Label: Address, Text: ANYTOWN , CA 95818
# Label: Restrictions, Text: NONE
# --------------------------------------------------
# Document Text: JOHN R . KASICH , GOVERNOR
# Donalda Petit Registrar , BAV
# 1820UL4736230000
# Class
# -
# OHICO
# Ohio
# USA
# DRIVER LICENSE
# IJOLIE
# 2ANGELINA
# a535 RIVER AVE .
# DAYTON , OH43558
# 40LICENSE NO . 3BIRTHDATE
# 4a SSUE DATE
# 05-21-2013
# TB451863
# 06-04-1975
# 9CLASS e EXP IRES
# 9a ENDORS 12 RES TR
# D
# 06-04-2017
# 1S Sex F 16Ht . 5 - 07 17WI , 130
# 18Eyec . BLU S Hatr BRO
# SRGAN
# angelina Aolie
# Label: License_Number, Text: 1820UL4736230000
# Label: State, Text: Ohio
# Label: Country, Text: USA
# Label: Document_Number, Text: TB451863
# Label: Restrictions, Text: TR
# Label: Class, Text: D
# Label: Sex, Text: F
# Label: Eyes, Text: BLU
# Label: Hair, Text: BRO
# Label: Last_Name, Text: JOLIE
# Label: First_Name, Text: ANGELINA
# Label: Address, Text: 535 RIVER AVE .
# DAYTON , OH43558
# Label: Height, Text: 5 - 07
# Label: Weight, Text: 130
# --------------------------------------------------
# Document Text: USA
# DRIVER LICENSE
# California
# FEDERAL
# LIMITS
# APPLY
# DL 85568240
# CLASS C
# EXP 02/01/2023
# LNADAMS
# END NONE
# FN IDINSTATE MIDDLE
# CIROS 3045 PATTILANE
# LANCASTER , CA 93535
# DOB 02/01/1995
# RSTRNONE
# 02011995
# SEXE F
# HAIR BLN
# EYES BLU
# AUS ISS
# Idingae
# HGT 5 '- 03 " WGT 135 lb
# DD 0828201853818/0JDM23
# 06/28/2018
# Label: Country, Text: USA
# Label: State, Text: California
# Label: License_Number, Text: 85568240
# Label: Class, Text: C
# Label: Endorsement, Text: NONE
# Label: First_Name, Text: IDINSTATE MIDDLE
# Label: State, Text: CIROS 3045
# Label: Last_Name, Text: PATTILANE
# Label: First_Name, Text: LANCASTER , CA 93535
# Label: Endorsement, Text: RSTRNONE
# Label: Document_Number, Text: 02011995
# Label: Sex, Text: F
# Label: Hair, Text: BLN
# Label: Eyes, Text: BLU
# Label: Last_Name, Text: ADAMS
# Label: Height, Text: 5 '- 03 "
# Label: Weight, Text: 135 lb
# Label: DD, Text: 0828201853818/0JDM23
# --------------------------------------------------
# Document Text: CALIFORNIA - e
# DRIVER LICENSE
# DL 11234562
# CLASS A
# END NONE
# EXP 08/31/2023
# LN DEPP
# FN JOHNNY
# 1000 Elysian Park Ave
# LOS ANGELES , CA 90012
# DOB 06/06/1963
# RSTR NONE
# 06061963
# 0806 63
# OONOE
# SEX M
# HAIR BLK
# EYES BRN
# HGT 5 - 11 " WGT 175 lb
# DD 06/06/1963DEPJO/62 . JU/23
# ISS .
# 09/30/2010
# Label: State, Text: CALIFORNIA
# Label: License_Number, Text: 11234562
# Label: Class, Text: A
# Label: Endorsement, Text: NONE
# Label: First_Name, Text: JOHNNY
# Label: Address, Text: 1000 Elysian Park Ave
#
# Label: Address, Text: LOS ANGELES , CA 90012
# Label: Restrictions, Text: NONE
# Label: Document_Number, Text: 06061963
# Label: Sex, Text: M
# Label: Hair, Text: BLK
# Label: Eyes, Text: BRN
# Label: Height, Text: 5 - 11 "
# Label: Weight, Text: 175 lb
# Label: Last_Name, Text: DEPP
# Label: DD, Text: 06/06/1963DEPJO/62 . JU/23
# --------------------------------------------------
# Document Text: WA WASHINGTON
# DRIVER LICENSE
# USA
# FEDERAL LIMITS APPLY
# 4d LIC # WDLBCKN489FB 9CLASS
# SPENCER
# 2JACOBJ
# 2
# - / - a
# -
# - -
# 3 DOB 05/18/1974
# 81S MAIN ST
# 4a Iss 05/11/2018
# SEATTLE WA 98104 - 2513
# 15 SEX M
# 16 HGT 5 '- 11 "
# 18 EYES BLU
# 17WGT 140 lb
# 12 RES TRICTIONS 9a END NONE
# NONE
# 46 EXP 05/18/2024
# Tignalunre -
# 5DD WDLBCKN489F8P0511184G0927
# REV 01/06/2015
# Label: State, Text: WA
# Label: State, Text: WASHINGTON
# Label: Country, Text: USA
# Label: License_Number, Text: WDLBCKN489FB
# Label: Address, Text: 81S MAIN ST
#
# Label: Sex, Text: M
# Label: Height, Text: 5 '- 11 "
# Label: Eyes, Text: BLU
# Label: Weight, Text: 140 lb
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: NONE
# Label: DD, Text: WDLBCKN489F8P0511184G0927
# Label: Address, Text: SEATTLE WA 98104 - 2513
# Label: Last_Name, Text: SPENCER
# Label: First_Name, Text: JACOBJ
# --------------------------------------------------
# Document Text: Bonurenbckwe npasa
# B CLA
# NEW
# YORK STATE
# Ruin l ho
# Commissioner of Motor Vehicles
# -
# ENHANCED
# DRIVER LICENSE
# D : 012
# DOCUMENT
# SAMPLE , LICENSE
# 2345 ANYPLACE AVE
# ANYTOWN NY 12345
# DOB : 06-09-85
# SEX : F EYES : BR HT : 5 - 09
# CLASS D
# E : NONE
# R : NONE
# ompl dicing ) Doumunt
# ISSUED : 09-30-08 EXP IRES : 10-01-16
# 8AJ120T521
# Label: Last_Name, Text: DOCUMENT
# Label: First_Name, Text: SAMPLE , LICENSE
# Label: Address, Text: 2345 ANYPLACE AVE
#
# Label: Sex, Text: F
# Label: Eyes, Text: BR
# Label: Height, Text: 5 - 09
# Label: Class, Text: D
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: NONE
# Label: Document_Number, Text: 8AJ120T521
# Label: State, Text: NEW
# YORK STATE
# Label: Address, Text: ANYTOWN NY 12345
# --------------------------------------------------
# Document Text: NORTH A - - VRE
# L
# -
# DRIVER LICENSE
# Kin Thomes
# 14
# 4d DLN 000004273464 31008 08/06/1976
# DUP
# 1 HORD
# 4DEXP 08/06/2019
# 2 BARBARA JO
# 8 411 GRAVES MILL RD
# KERNERSVILLE , NC 27284 - 2624
# 9 CLASS C
# 12RES TR 1
# 15SEX F
# 9END NONE
# BEYES BRO
# 16HGT 5 - 03 " 19HAIR BLN RACE
# Babmi Ke 4a1ss 06/25/2015
# 6 : DD 0013688053
# 08/06/76
# Label: State, Text: NORTH A
# Label: License_Number, Text: 000004273464
# Label: Last_Name, Text: BARBARA
# Label: First_Name, Text: JO
# Label: Class, Text: C
# Label: Restrictions, Text: 1
# Label: Sex, Text: F
# Label: Endorsement, Text: NONE
# Label: Eyes, Text: BRO
# Label: Height, Text: 5 - 03 "
# Label: Hair, Text: BLN
# Label: DD, Text: 0013688053
# Label: Address, Text: 411 GRAVES MILL RD
# KERNERSVILLE , NC 27284 - 2624
# --------------------------------------------------
# Document Text: CALIFORNIA USA DRIVER LICENSE
# DL 11234562
# CLASS A
# END NONE
# EXP 08/31/2014
# LN SAMPLE
# FN ALEXANDERJ .
# 2570 24TH STREET
# SACRAMENTO , CA 95818
# DOB 08/31/1977
# RSTR NONE
# 08311977
# DONOR
# SEX M
# RAIR BLK
# EYES BRN
# Alefander Jample
# HGT 5 - 08 " WGT 150 lb
# DD 00/00/0000NNNANJANFDIYY
# ISS
# 08/31/2009
# Label: State, Text: CALIFORNIA
# Label: Country, Text: USA
# Label: License_Number, Text: 11234562
# Label: Class, Text: A
# Label: Endorsement, Text: NONE
# Label: Last_Name, Text: SAMPLE
# Label: First_Name, Text: ALEXANDERJ
# Label: Address, Text: 2570 24TH STREET
# Label: Address, Text: SACRAMENTO , CA 95818
# Label: Restrictions, Text: NONE
# Label: Document_Number, Text: 08311977
# Label: Other, Text: DONOR
# Label: Sex, Text: M
# Label: Hair, Text: BLK
# Label: Eyes, Text: BRN
# Label: Height, Text: 5 - 08 "
# Label: Weight, Text: 150 lb
# Label: DD, Text: 00/00/0000NNNANJANFDIYY
# --------------------------------------------------
# Document Text: MIICHIGANE
# DRIVER LICENSE
# - s
# D6 616 067 108 368
# DOB 10-23-1965
# STAN LARSON
# 719 AUGUST RD .
# MUSKEGON MI , 49441
# ISS 04-01-2015
# EXP 05-01-2020 102365
# Sex M
# Lic Type 0
# Hgt 585
# End NONE
# Eyes BRO
# Res trictions NONE
# c
# DONOR -
# Rev01-21-2011
# DD 0130002456789
# Label: State, Text: MIICHIGANE
# Label: License_Number, Text: D6 616 067 108 368
# Label: License_Type, Text: 0
# Label: Height, Text: 585
# Label: Endorsement, Text: NONE
# Label: Eyes, Text: BRO
# Label: Restrictions, Text: NONE
# Label: Other, Text: DONOR
# Label: DD, Text: 0130002456789
# Label: Document_Number, Text: 102365
# Label: Last_Name, Text: STAN
# Label: First_Name, Text: LARSON
# Label: Address, Text: 719 AUGUST RD .
# MUSKEGON MI , 49441
# Label: Sex, Text: M
# --------------------------------------------------
# Document Text: KANSAS
# DRIVER ' S LICENSE
# NDERZUNTLS 1115201
# a UICNO .
# K12-34-5679
# 3 008
# 11/15/1998
# 2 CLASS A
# 9a END NONE
# 12RES T NONE
# dal 1S5 11/15/2017
# 461 EXP 11/15/2023
# Nick Sample
# SAMPLE
# 2 NICK
# APT . 2
# 15 SEX M
# - 123 NORTH STREET
# TOPEKA , KS 66612 - 1234
# 161 HGT 6 - 02 " 58 EYES BRO
# 17 WOT 170 lb
# 11/15/98
# 5 CO XX123XWMXCX1
# 23XWMX122
# DONOR
# Label: State, Text: KANSAS
# Label: License_Number, Text: K12-34-5679
#
# Label: Class, Text: A
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: NONE
# Label: Last_Name, Text: SAMPLE
# Label: First_Name, Text: 2 NICK
# Label: Address, Text: APT .
# Label: Address, Text: 2
# 15 SEX M
#
# Label: Address, Text: 123 NORTH STREET
# TOPEKA , KS 66612 - 1234
# Label: Height, Text: 6 - 02 "
# Label: Eyes, Text: BRO
# Label: DD, Text: XX123XWMXCX1
# Label: DD, Text: 23XWMX122
# Label: Other, Text: DONOR
# Label: Sex, Text: M
# Label: Weight, Text: 170 lb
# --------------------------------------------------
# Document Text: N USA INDIANA bmw Ngor
# OPERATOR DRIVER LICENSE
# - - - - - - *
# PROBATIONARY
# 023
# DONOR
# 15Sex -
# 16 Hgt 5 - 04
# 17Wgt 120
# B Eyes HAZ
# 19Hair BLO
# STATE
# Heididample
# %
# Ad DLN 1234-56-7890
# 4alss 07/04/2006 4b Exp 07/04/2010
# SAMPLE
# 2HEIDI
# -
# 8123 SAMPLE DRIVE
# d
# APT B
# Clase
# 12 Res AC
# INDIANAPOLIS , IN46204 - 0000
# al End P
# 3 DOB 07/04/1989
# D Transaction 07040602300001
# Label: Country, Text: USA
# Label: State, Text: INDIANA
# Label: Other, Text: DONOR
# Label: Height, Text: 5 - 04
# Label: Weight, Text: 120
# Label: Eyes, Text: HAZ
# Label: Hair, Text: BLO
# Label: Last_Name, Text: SAMPLE
# Label: Endorsement, Text: P
# Label: DD, Text: 07040602300001
# Label: License_Number, Text: 1234-56-7890
# Label: Address, Text: 8123 SAMPLE DRIVE
# Label: Address, Text: APT B
# Label: Restrictions, Text: AC
# Label: Address, Text: INDIANAPOLIS , IN46204 - 0000
# Label: First_Name, Text: HEIDI
# --------------------------------------------------
# Document Text: USA
# TX
# DRIVER
# Texas
# LICENSE
# ÃƒÂ
# 4d DL 39175097
# 4a Iss 01/23/2021
# 3 DOB 07/23/1998
# Class C
# 4b Exp 07/23/2026
# CFAKEIDNDL
# 2IDKING
# 8 2915 CHALET KNOLLS LN
# KATY TX 77494
# 07239
# s
# 12 Res trictions NONE
# 9a End NONE
# Alaidadl
# 16 Hgt 5 - 07
# 15 Sex F 18 Eyes BLK DONOR
# . DD 00596875402103051482
# Label: License_Number, Text: L 391750
# Label: Class, Text: s
# Label: Restrictions, Text: s NO
# Label: Endorsement, Text: d NO
# Label: Height, Text: t 5 -
# Label: Sex, Text: x
# Label: Eyes, Text: s B
# Label: Other, Text: K DON
# Label: DD, Text: D 005968754021030514
# Label: Country, Text: USA
# Label: State, Text: Texas
# Label: State, Text: TX
# Label: Last_Name, Text:
# CFAKEIDN
# Label: First_Name, Text:
# 2IDKI
# Label: Address, Text:  2915 CHALET KNOLLS LN
# KATY TX 774
# Label: Document_Number, Text: 4
# 072
# --------------------------------------------------
# Document Text: Colorado
# Driver License
# 14 - 042 - 0777 Exp ires : 06-07-2014
# Class : R
# End :
# Res t :
# Issued : 03-12-2014
# DOB : 08-22-1992
# Previous Type : N
# Ht : 5 ' 04 " Wt : 119 Eyes : GRN
# Sex : F
# TARN ALEXANDRA RODGERS JOHNS
# BOULDER , CO 80303
# Label: Class, Text: R
# Label: License_Type, Text: N
# Label: Height, Text: 5 ' 04 "
# Label: Weight, Text: 119
# Label: Eyes, Text: GRN
# Label: Sex, Text: F
#
# Label: License_Number, Text: 14 - 042 - 0777
# Label: Address, Text: TARN ALEXANDRA RODGERS JOHNS
# BOULDER , CO 80303
# --------------------------------------------------
# Document Text: USA
# TX
# -
# DRIVER
# Texas
# LICENSE ETEET
# ce
# DIRECIOR
# 4d DL 24255226
# 9 Class C -
# 4a Iss 07/09/2014
# 4b Exp 07/01/2020
# 3 DOB 07/01/1980
# - - E
# -
# 1 STERLING
# 2ALISON
# 84151 WEST YOAKUM AVE
# KINGSVILLE , TX 78363
# 12 Res trictions NONE
# ga End NONE
# 16
# - -
# Hgt 5 - 04
# 15 Sex F 18
# -
# a
# e
# BRO
# Eyes
# DONOR
# 5 DD 5236521412589652478
# Label: Country, Text: USA
# Label: State, Text: TX
# Label: State, Text: Texas
# Label: License_Number, Text: 24255226
# Label: Class, Text: C
# Label: Address, Text: 84151 WEST YOAKUM AVE
#
# Label: Address, Text: KINGSVILLE , TX 78363
# Label: Restrictions, Text: NONE
# Label: Endorsement, Text: NONE
# Label: Height, Text: 5 - 04
# Label: Sex, Text: F
# Label: Eyes, Text: BRO
# Label: Other, Text: DONOR
# Label: DD, Text: 5236521412589652478
# Label: Last_Name, Text: STERLING
# Label: First_Name, Text: ALISON
# --------------------------------------------------
# Document Text: USA
# TX
# -
# Texas - -
# DRIVER LICENSE
# 4d DL 16564745
# 4a Iss 04/06/2017
# 9 Class C
# 4b Exp 04/20/2024
# 3 DOB 04/20/1995
# 1 FAKES
# 2 DINGO
# 8 15820 CROWLEY RD
# CONROE TX 77306 - 6952
# 12 Res trictions NONE
# Da End NONE
# Ding
# Fakes
# 16 Hgt 5 - 07
# 15 Sex M 18 Eyes BLK
# 5 DD 09110601361122354773
# Label: State, Text: Texas
# Label: License_Number, Text: 16564745
# Label: Class, Text: C
# Label: Last_Name, Text: FAKES
# Label: Address, Text: 15820 CROWLEY RD
# CONROE TX 77306 - 6952
# Label: Restrictions, Text: NONE
# Label: Endorsement, Text: NONE
# Label: Height, Text: 5 - 07
# Label: Sex, Text: M
# Label: Eyes, Text: BLK
# Label: First_Name, Text: DINGO
# Label: DD, Text: 09110601361122354773
# Label: Country, Text: USA
# Label: State, Text: TX
# --------------------------------------------------
# Document Text: WA
# USA WASHINGTON
# DRIVER LICENSE
# Ad LICE BRAUNWH559RC
# - - - -
# 1 BRAUN JR
# 2WILLARD HARRY
# DOB 12-03-1945
# S5 10-27-2009
# - 123 MAIRST
# BETKAIRWANSTEOOY
# 158 X
# Hgt 5 - 87
# 4W9r188 18 Eyes BRN
# abs
# 9a End NONE
# 4b Exp 12-03-2014
# Res trictions C
# wuil
# SDD BRAUNWHSSARC3203005C1359
# Rev M - 1620 )
# Label: State, Text: WA
# Label: Country, Text: USA
# Label: State, Text: WASHINGTON
# Label: License_Number, Text: BRAUNWH559RC
#
# Label: Address, Text: 123 MAIRST
#
# Label: Address, Text: BETKAIRWANSTEOOY
#
# Label: Height, Text: 5 - 87
# Label: Eyes, Text: BRN
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: C
# Label: DD, Text: BRAUNWHSSARC3203005C1359
# Label: Last_Name, Text: BRAUN JR
# Label: First_Name, Text: WILLARD HARRY
# Label: Weight, Text: 188
# --------------------------------------------------
# Document Text: MCHIGANE
# ENHANCED
# a
# DRIVER LICENSE
# S514778585159
# DOB 03-01-1982
# ISS 03-01-2016
# EXP 03-01-2020
# SUZY MARIE SAMPLE
# 123 NORTNSTATEST .
# LANSING , Mi418 - 1234
# 03-01-1382
# Sex F
# Hgt 504
# End NONE
# Eyes BRO
# Lic Type E , 0
# Res trictions NONE
# yy
# Jonpd .
# DONOR
# -
# DD 1234587030123
# Label: State, Text: MCHIGANE
# Label: License_Number, Text: S514778585159
# Label: First_Name, Text: MARIE SAMPLE
# Label: Sex, Text: F
# Label: Height, Text: 504
# Label: Endorsement, Text: NONE
# Label: Eyes, Text: BRO
# Label: Restrictions, Text: NONE
# Label: Other, Text: DONOR
# Label: DD, Text: 1234587030123
# Label: Last_Name, Text: SUZY
# Label: Address, Text: 123 NORTNSTATEST .
# LANSING , Mi418 - 1234
# Label: License_Type, Text: E , 0
# --------------------------------------------------
# Document Text: WA
# ENHANCED
# USA WASHINGTON
# DRIVER LICENSE
# 4d
# 9CLASS
# DONOR
# LICHWDLABCD456DG
# 1 SAMPLE
# 2JOHNA
# 3 DOB 01/06/1958
# 4a ISS 01/06/2015
# 8123 STREET ADDRES S
# YOUR CITY WA 99999 - 1234
# 15 SEX M
# 16 HGT 5 '- 08 "
# 18 EYES DIC
# 17 WGT165 Ib
# 12 RES TRICTIONS 9a END NONE
# NONE
# 4b EXP 08/12/2020
# -
# -
# SDD SAMPLJA185801234567XX1108
# Aohm A Somy
# Veteran
# REV 07/01/2018
# Label: State, Text: WA
#
# Label: Country, Text: USA
# Label: State, Text: WASHINGTON
# Label: Other, Text: DONOR
# Label: Last_Name, Text: SAMPLE
# Label: Address, Text: 8123 STREET ADDRES S
#
# Label: Address, Text: YOUR CITY WA 99999 - 1234
# Label: Sex, Text: M
# Label: Height, Text: 5 '- 08 "
# Label: Endorsement, Text: NONE
# Label: Restrictions, Text: NONE
# Label: DD, Text: SAMPLJA185801234567XX1108
# Label: Eyes, Text: DIC
# Label: Weight, Text: 165 Ib
# Label: License_Number, Text: WDLABCD456DG
# Label: First_Name, Text: JOHNA
# Label: Other, Text: Veteran
# --------------------------------------------------
# Document Text: -
# U3A
# ME
# MAI
# DRIVER ' S
# CICENSE
# Matthew Dunlap , Ssarucary of State
# 1 ADAMS
# RIDINSTATE MIDDLE
# 23 SILVER RDG
# VEAZIE , ME 04401
# 40 1746570
# 4a ISSUED
# 10/05/2016
# 40 EXP IRES
# 02/01/2021
# 300B
# 02/01/1995
# 15 GENDER 16 HEIGHT 17 WEIGHT 18 EYES 19 HAIR
# F
# 5 ' 03 "
# 135
# BU
# BL
# dinsoe
# CLASS C
# 12 RES T
# 9a ENDS
# ORGAN
# DONOR
# Label: Last_Name, Text: ADAMS
# Label: First_Name, Text: RIDINSTATE MIDDLE
# Label: Address, Text: 23 SILVER RDG
# VEAZIE , ME 04401
# Label: Sex, Text: F
# Label: Height, Text: 5 ' 03 "
# Label: Weight, Text: 135
# Label: Eyes, Text: BU
# Label: Class, Text: C
# Label: Other, Text: ORGAN
#
# Label: Other, Text: DONOR
# Label: Document_Number, Text: 1746570
# Label: Hair, Text: BL
# --------------------------------------------------
# Document Text: CALIFORNIA DRIVER LICENSE
# OL 11234568
# LASS C
# IND NONE
# EXP 08/31/2015
# LNCARDHOLDER
# FN IMA
# 2570 24TH STREET
# SACRAMENTO , CA 95818
# 008 08/31/1977
# RSTR NONE
# - - ÃƒÂ  se
# 08311977
# D831
# SEX F
# MAIR BRN EYES BRN
# Dmar Candloldn MOT 5 . 05 " WGT 1251
# S
# 08/30/2010
# ppws - X2010ME72/TU0NS
# DRIVING PRIVILEGES ONLY
# Label: State, Text: CALIFORNIA
# Label: License_Number, Text: 11234568
# Label: Class, Text: C
# Label: Endorsement, Text: NONE
# Label: First_Name, Text: IMA
# Label: Address, Text: 2570 24TH STREET
# Label: Address, Text: SACRAMENTO , CA 95818
# Label: Restrictions, Text: NONE
# Label: Document_Number, Text: e
# 083119
# Label: Sex, Text: X
# Label: Hair, Text: R B
# Label: Eyes, Text: S B
# Label: Height, Text: T 5 . 05
# Label: Weight, Text: T 12
# Label: Last_Name, Text: CARDHOLDER
# --------------------------------------------------
# Document Text: CALIFORNIA DRIVER LICENSE
# Ã¢â€šÂ¬
# DL D7632615
# CLASS C
# ENDI NONE
# EXP 04/13/2020
# LN EVERETTE
# FN ANTIONE
# 16209 JESSIGA CIR
# CERRITOS , CA 90703
# DOB 04/13/1979
# RSTR NONE
# 04131979
# QU - : - -
# SEX M
# HA
# EYES BRN
# ÃƒÂ  ÃƒÂ  harwetts
# HGT 5 - 07 " WGT 165 lb ISS
# DD 05002015511788F028
# 05/08/2015
# Label: State, Text: CALIFORNIA
# Label: License_Number, Text:
# DL D763
# Label: Class, Text: A
# Label: Endorsement, Text: NDI
# Label: First_Name, Text:
# FN ANT
# Label: Restrictions, Text: STR
# Label: Sex, Text: S
# Label: Eyes, Text: YES
# Label: DD, Text:  ISS
# DD 0500201551
# Label: Last_Name, Text:
# LN EVER
# Label: Address, Text: ONE
# 16209 JESSIGA CIR
# CERRITOS , CA 9
# Label: Height, Text: tts
# HGT
# Label: Weight, Text: 7 " WG
# Label: Document_Number, Text: ONE
# 0413
# --------------------------------------------------
# Document Text: WA .
# USA WASHINGTON
# DRIVERLICENSE
# ALI Ce SMITJABO7LG
# ...
# he
# Ther Odmjan Ã  RES TE
# COND
# D08DN1997/10/10
# 3948384 "
# Label: State, Text: Ontaro
# Label: Country, Text: CANADA
# Label: Last_Name, Text: ODINSON
# Label: License_Number, Text: 05654 - 45349 - 27634
# Label: Height, Text: 210 cm
# Label: DD, Text: RT5948374
# Label: Sex, Text: M
# Label: Document_Number, Text: 3948384
# Label: First_Name, Text: THOR , HAMMER
# Label: Address, Text: 69 BIG HAMMER LANE
# OTTAWA , ON , K1R 7Y5
# Label: License_Number, Text: 05654 45349 - 2769
# --------------------------------------------------
# Document Text: Driver ' s Licence
# SHANAHAN . NAMENON
# PETER
# 12770 Aquitaine ONLSN 3K5
# Streetsville ,
# NUVERO
# GISSOEL 2017/05/07
# SDDREF DN3573301
# 1 SECSOE M
# a
# aplasse
# AT EST
# N
# ON
# Ontario
# Permis de conduire CANADA
# Ave
# ANUMBER : S4838 - 53366 - 80606
# AXEXP IEXP 2022/06/06
# 16HSTHAUT 170 cm
# 4838 - 53166 - 80606
# 1968/06/06
# PARL
# Su y V .
# Dl
# 1968/06/06
# Label: First_Name, Text: PETER
# Label: DD, Text: DN3573301
# Label: State, Text: ON
# Label: State, Text: Ontario
# Label: State, Text: CANADA
# Label: License_Number, Text: S4838 - 53366 - 80606
# Label: Height, Text: 170 cm
# Label: License_Number, Text: 4838 - 53166 - 80606
# Label: Last_Name, Text: SHANAHAN
# Label: Address, Text: 12770 Aquitaine ONLSN 3K5
# Label: Sex, Text: M
# Label: Address, Text: Streetsville
# --------------------------------------------------
# Document Text: Driver ' s Licence
# Permis de conduire
# ON
# CANADA
# Ontarto
# NAME NOME
# GRITS ,
# BORIS
# 146 BURROWS HALL RD
# SCARBOROUGH , ON , M1B 1H6
# ANUMBLK NMERO
# AKISSIDEL
# EODREE
# SEGEXE M
# CASE
# CATEG
# 1 RES T
# COND
# 9538018 "
# G7456 - 09406 - 81226
# 2011/05/31
# CA5470419
# REXP JEXP 2016/05/30
# MENGTIMAUT 167 cm
# pug .
# 33080CH 1968/12/26
# Label: State, Text: ON
# Label: Country, Text: CANADA
# Label: Document_Number, Text: 9538018
# Label: License_Number, Text: G7456 - 09406 - 81226
# Label: Height, Text: 167 cm
# Label: State, Text: Ontarto
# Label: Last_Name, Text: GRITS
# Label: First_Name, Text: BORIS
# Label: Address, Text: 146 BURROWS HALL RD
# SCARBOROUGH , ON , M1B 1H6
# Label: Sex, Text: M
# Label: DD, Text: CA5470419
# --------------------------------------------------
# Document Text: IDENTIFICATION CARD
# CARTE D ' IDENTITE
# 12NAME/NOM
# PUBLIC
# MB
# CAN
# Manitoba
# JAMES QUINTIN
# 4G . NUMBERNUMERO
# 123456790
# B 123 ANY STREET
# BRANDON MB < 0Z OZO
# ta JSS/DEL 2015/08/18 Ab EXP EXB
# - DO/REF 987654321 15 . GENDERI
# 2015/08/17
# M
# SEXE
# 18 EYES T BRO/BRN
# YEUX
# 123456790
# 2015/08/18
# Sonsa P Ae
# Somes Q Public 16 . HGTI 183 cm
# HAUT
# 3 . DOB/DDN 1985/08/09
# Label: First_Name, Text: JAMES QUINTIN
#
# Label: License_Number, Text: 123456790
# Label: Address, Text: 123 ANY STREET
# BRANDON MB < 0Z OZO
# Label: DD, Text: 987654321
# Label: Last_Name, Text: GENDERI
#
# Label: Sex, Text: M
# Label: License_Number, Text: 123456790
# Label: Country, Text: CAN
# Label: Last_Name, Text: Manitoba
# Label: State, Text: MB
# Label: Eyes, Text: BRO/BRN
# Label: Height, Text: 183 cm
# --------------------------------------------------
# Document Text: DRIVERS LUCENC Ea Nd SERVIGES - CARID
# British Columbia -
# CAN
# SAMPLE ,
# TEST CARD
# DL : 1234567
# issued : 2012 - Nov - 30 DOB 1979 - Jun - 07
# Exp ires : 2017 - Nov - 30
# Res trictions
# Endorsements : 21
# Class : 5
# BRITISH
# Wt : 51 . 0 kg HE : 175 cm COLUMBIA
# Sex : F
# Eyes : BLU Hair : BRN
# 910 GOVERNMENT STREET
# VICTORIA BC V8W 3Y8
# dampe
# Label: State, Text: British
# Label: State, Text: Columbia
# Label: Country, Text: CAN
# Label: Last_Name, Text: SAMPLE
# Label: License_Number, Text: 1234567
# Label: Class, Text: 5
#
# Label: State, Text: BRITISH
# Label: Weight, Text: 51 . 0 kg
# Label: Height, Text: 175 cm
# Label: State, Text: COLUMBIA
# Label: Sex, Text: F
# Label: Eyes, Text: BLU
# Label: Hair, Text: BRN
# Label: First_Name, Text: TEST CARD
# Label: Endorsement, Text: 21
# Label: Address, Text: 910 GOVERNMENT STREET
# VICTORIA BC V8W 3Y8
# --------------------------------------------------
# Document Text: Enhanced Driverslicence
# Permis de conduire . plus
# Ontanto
# CAN
# LENAMENOM
# JUSTIN DREW
# BIEBER
# 123ANY STREET
# TORONTO , ON , MOM OMO
# ad NUMBERI B0122 - 35012 -
# NUMERO
# AISSIDEL
# - 222321
# 2012/12/22
# MZ2043307
# 401 EXP/EXP , 2023/03/01
# 16HGT/HAUT . 178 cm
# FODIREF
# 16 SEXISEKE M
# 79CLASS E
# CATEG :
# 2RES T
# COND ,
# G2
# 80122 - 35012 - 2232
# 1994/03/01
# DIN
# ON -
# ABODN 1994/03/01
# * 4980342 *
# Label: State, Text: Ontanto
# Label: Country, Text: CAN
# Label: Last_Name, Text: JUSTIN
# Label: Last_Name, Text: DREW
# Label: First_Name, Text: BIEBER
# Label: License_Number, Text: B0122 - 35012 -
#
# Label: License_Number, Text: 222321
# Label: DD, Text: MZ2043307
# Label: Height, Text: 178 cm
# Label: Sex, Text: M
# Label: Class, Text: G2
# Label: License_Number, Text: 80122 - 35012 - 2232
# Label: Document_Number, Text: 4980342
# Label: Address, Text: 123ANY STREET
# TORONTO , ON , MOM OMO
# --------------------------------------------------
# Document Text: DRIVER ' S LICENCE
# BRANISHICOUUMBVAN CANADA
# CAN
# BRITISH
# COLUMBIA
# DL : 8960184
# The Best Place on Earth DAVIS ,
# KELLY ANNE
# Issued : 2011 - Aug - 17
# Exp ires : 2013 - May - 02
# 1986 - May - 02
# Class : 5
# Res trictions/
# Endorsements :
# Sex : F
# WE : 65 . 0kg
# Eyes : GRN Hair : BLO
# Ht : 175cm
# 1 - 1868 12TH AVE W
# VANCOUVER BC V6J2E8
# M
# Label: Country, Text: CANADA
# Label: Country, Text: CAN
# Label: State, Text: BRITISH
# Label: State, Text: COLUMBIA
# Label: License_Number, Text: 8960184
# Label: Last_Name, Text: DAVIS
# Label: First_Name, Text: KELLY ANNE
# Label: Class, Text: 5
# Label: Sex, Text: F
# Label: Eyes, Text: GRN
# Label: Eyes, Text: BLO
# Label: Weight, Text: 175cm
# Label: Address, Text: 1868 12TH AVE W
# VANCOUVER BC V6J2E8
# Label: Weight, Text: 65 . 0kg
# --------------------------------------------------
# Document Text: EE
# Qu Ã© bec BE
# Permis de conduire
# L1531 - 171274 - 08
# 4d
# LAPOINTE
# 2 ANNE - MARIE
# 3 Date de naissance ( A - M - J ) 1974-12-17
# 8 333 , BOULEVARD JEAN - LESAGE
# APP . 432
# QU Ã‰ BEC ( QC ) G1K 8J6
# 15 Sexe $ F
# 5 6A
# 9 Class e ( s ) - 1234 4A
# 12 Cond . C AC
# 9a Mention ( s ) F M T
# 16 Taille ( cm ) 168
# 18 Yeux BLEU
# 5 No de r Ã© ference . PB M H92V70
# 4a Valide le : 2014-10-01 4b Exp ire le 2022-12-17
# Paiement exig Ã© chaque ann Ã© e Ã  votre
# date anniversaire de naissance
# Clushiane lapmle
# Label: License_Number, Text: L1531 - 171274 - 08
# Label: Last_Name, Text: LAPOINTE
# Label: Sex, Text: F
# Label: Height, Text: 168
# Label: First_Name, Text: ANNE - MARIE
# Label: Address, Text: 333 , BOULEVARD JEAN - LESAGE
# APP . 432
# QU Ã‰ BEC ( QC ) G1K 8J6
# Label: Class, Text: 1234 4A
# Label: Restrictions, Text: AC
# Label: Endorsement, Text: F M T
# Label: Eyes, Text: BLEU
# Label: DD, Text: PB M H92V70
# --------------------------------------------------
# Document Text: DRIVER ' S LICENCE
# CAN
# BRAISHICOLUMBIANICANADA
# BRITISH
# COLUMBIA
# The Bat Pace on Earth
# DL : 1234567
# TEST
# SAMPLE ONE
# Issued : 2008 - Jun - 07
# Exp ires : 2013 - Jun - 07
# 1979 - Jun - 07
# Class : 5
# Res trictions !
# Endorsements ; 21
# Sex : F
# Eyes : BLU Hair : BRN
# 1979
# WE : 50 . 9kg
# Ht : 175cm
# 910 GOVERNMENT STREET
# VICTORIA BC V8W3Y8
# Sampajest
# Label: Country, Text: CAN
# Label: License_Number, Text: 1234567
# Label: Last_Name, Text: TEST
# Label: First_Name, Text: SAMPLE
# Label: Class, Text: 5
# Label: Sex, Text: F
# Label: Eyes, Text: BLU
# Label: Hair, Text: BRN
# Label: Height, Text: 175cm
# Label: State, Text: BRITISH
# Label: State, Text: COLUMBIA
# Label: First_Name, Text: ONE
# Label: Endorsement, Text: 21
# Label: Weight, Text: 50 . 9kg
# Label: Address, Text: 910 GOVERNMENT STREET
# VICTORIA BC V8W3Y8
# --------------------------------------------------
# Document Text: DKINVEK 0 LICENCE CAN
# BRAMISHICORUMBJANCANADA
# BRITISH
# COLUMBIA
# DL : 1234567
# TEST
# The Best Mace on Earth
# SAMPLE ONE
# Issued : 2008 - Jun - 07
# 1979 - Jun - 07
# Exp ires : 2013 - Jun - 07
# Class : 5
# Res trictionsf
# Endorsements : 21
# Sex : F
# Eyes : BLU Hair : BRN
# 1979
# Wt : 50 . 9kg
# Ht : 175cm
# 910 GOVERNMENT STREET
# VICTORIA BC V8W3Y8
# 8 - -
# Ã
# Label: Country, Text: CAN
# Label: State, Text: BRITISH
# Label: State, Text: COLUMBIA
# Label: License_Number, Text: 1234567
# Label: Eyes, Text: BLU
# Label: Hair, Text: BRN
# Label: Height, Text: 175cm
# Label: Last_Name, Text: TEST
# Label: First_Name, Text: SAMPLE ONE
# Label: Class, Text: 5
# Label: Endorsement, Text: 21
# Label: Sex, Text: F
# Label: Weight, Text: 50 . 9kg
# Label: Address, Text: 910 GOVERNMENT STREET
# VICTORIA BC V8W3Y8
# --------------------------------------------------
# Document Text: DRIVER ' S LICENCE
# PERMIS DE CONDUIRE
# MPL INSURANCE CERTIFICATE
# CERTIFICAT DASSURANCE
# ZODINSON
# Manitoba
# MB
# CAN
# DE LA : SAPM .
# THOR HAMMER
# a 69 BIG HAMMER LANE
# NOTRE - DAME - DE - LOURDES MB
# du UCENCEL OD - IN - ST - H109NA
# -
# Ã
# PERMIS
# 4a ISSENEL
# JAE CO0ESCOULS
# CESOATES
# 2011/02/02 2015/12/07
# 5 DEVREF
# L Ã  - SIAECLASS E ETAPE
# Da ENDENDOSS
# N
# 687654321 5F
# a EYES YEUX
# BRO/BRN
# 12 . RES IRICTEONS
# OD - IN - ST - H109NA
# 1989/08/08
# M GENDERISEXE 1e , HGTHAUT
# M
# 199 cm
# T Udinson
# 3 COBLORN 1989/08/08
# Label: State, Text: Manitoba
# Label: State, Text: MB
# Label: Country, Text: CAN
# Label: Address, Text: 69 BIG HAMMER LANE
#
# Label: DD, Text: 687654321
# Label: Eyes, Text: YEUX
# Label: Eyes, Text: BRO
# Label: Eyes, Text: BRN
# Label: Last_Name, Text: ODINSON
# Label: First_Name, Text: THOR HAMMER
# Label: Address, Text: NOTRE - DAME - DE - LOURDES MB
# Label: License_Number, Text: OD - IN - ST - H109NA
# Label: Class, Text: 5F
# Label: Endorsement, Text: N
# Label: License_Number, Text: OD - IN - ST - H109NA
# Label: Sex, Text: M
# Label: Height, Text: 199 cm
# --------------------------------------------------
# Document Text: Service Ontario . ca
# X C - CONONTIONS JJ2018123
# Driver ' s Licence
# NAME NOM
# DOE
# JOHN LEE
# 123 ANYWHERE STREET
# TORONTO , ON , M4P 1R2
# NUMBER
# NUMERO W1234
# ON
# Ontarto Permis de conduire CANADA
# 12345 - 12345
# " 9918069 "
# 1 ISSDEL 2018/12/15 4b EXP JEXP 2023/12/15
# OREF JJ2018123 MEHGTIHAUT 175 cm
# Sen SEXE M
# CLASS I D
# CATEG
# E St
# COND
# M
# 19851016
# heri
# DOB OON 1986/10/16
# Label: State, Text: Ontario
# Label: Last_Name, Text: DOE
# Label: Document_Number, Text: JJ2018123
# Label: Height, Text: 175 cm
# Label: Sex, Text: M
# Label: DD, Text: 19851016
# Label: First_Name, Text: JOHN LEE
# Label: Address, Text: 123 ANYWHERE STREET
# TORONTO , ON , M4P 1R2
# Label: State, Text: ON
# Label: Country, Text: CANADA
# Label: License_Number, Text: W1234
# Label: License_Number, Text: 12345 - 12345
# Label: Class, Text: D
# Label: Document_Number, Text: 9918069
# --------------------------------------------------
# Document Text: NEW DRIVER ' S LICENCE
# BARADI
# Alberta DRIVER ' S LICENCE
# No 134711 - 320 Class 56
# Cond/End None
# Exp 20 NOV 2023
# SAMPLE , Sam
# 241 My Place Street
# Anywhere AB T5J 2M6
# DOB 20 NOV 1971
# Sex M Eyes Bro Hair Bro 2ONOV
# Ht 182 cm wi83 kg
# Iss 17 MAY 2018
# 1971SAP
# -
# A 2 a
# 1y
# DONOR
# 0006 - 81780
# Label: State, Text: Alberta
# Label: First_Name, Text: Sam
# Label: Sex, Text: M
# Label: Height, Text: 182 cm
# Label: Other, Text: DONOR
# Label: License_Number, Text: 134711 - 320
# Label: Class, Text: 56
# Label: Address, Text: 241 My Place Street
# Anywhere AB T5J 2M6
# Label: Eyes, Text: Bro
# Label: Hair, Text: Bro
# Label: Weight, Text: 83 kg
# Label: Document_Number, Text: 0006 - 81780
# Label: Endorsement, Text: None
# Label: Last_Name, Text: SAMPLE
# --------------------------------------------------
# Document Text: Pnince Edward Island
# CAN
# PSR Te - du . frincefdouard Driver Licence I Permis de conduire PE
# 4d . No/N 242341
# 4a . Iss/D Ã© l 2017/09/26
# 4b . Exp 2020/09/26 3 . DOB/DDN 1984/08/08
# 1 . PUBLIC
# 2JOAN Q
# 8 . 1213 ANYWHERE ST .
# ANYTOWN , PE COT 1D5
# 15 . F
# 16 . Hgt/Taille 166 cm
# 18 . Eyes/Yeux BLU BLE
# 9 . Class/Class e 5
# -
# 9a . End/Mention NONE
# 5 . DD/Re IDD 242341
# 12 Res t/Cond NONE
# 1984/08/08
# Label: License_Number, Text: 242341
# Label: Last_Name, Text: PUBLIC
# Label: Address, Text: 1213 ANYWHERE ST .
# ANYTOWN , PE COT 1D5
# Label: Sex, Text: F
# Label: Weight, Text: 166 cm
# Label: Eyes, Text: BLU
# Label: Height, Text: 5
# -
#
# Label: Endorsement, Text: NONE
# Label: License_Number, Text: 242341
# Label: Restrictions, Text: NONE
# Label: First_Name, Text: JOAN Q
# Label: Eyes, Text: BLE
# --------------------------------------------------
# Document Text: ER
# Qu Ã© bec EE
# Permis de conduire
# 4d
# -
# L5843 - 300489 - 99 a
# LAPOINTE
# 2 ANNE - MARIE
# Date de naissance ( A - M - J ) : 1989-04-30
# 333 , BOULEVARD JEAN - LESAGE
# QUEBEC
# ( QC ) G1K 8Z2
# 15 Sexe : F
# Class e ( s ) 1234C 5 6E
# 12 Cond . : AC
# 9a Mention ( s ) : FMT
# 16 Taille ( cm '
# 18 Yeux : BI
# No de r Ã© f Ã© rence : PC6222VX1
# 4a Valide le : 2015-09-04 4b Exp ire le : 2011
# Paiement
# date anniversaire
# ann Ã© e
# de naissance
# -
# Tuess
# dm
# exig Ã© chaque
# Ã  voi
# Label: License_Number, Text: L5843 - 300489 - 99
# Label: Last_Name, Text: LAPOINTE
# Label: Sex, Text: F
# Label: Endorsement, Text: FMT
# Label: Eyes, Text: BI
# Label: DD, Text: PC6222VX1
# Label: First_Name, Text: ANNE - MARIE
# Label: Address, Text: 333 , BOULEVARD JEAN - LESAGE
# QUEBEC
# ( QC ) G1K 8Z2
# Label: Class, Text: 1234C 5 6E
# Label: Restrictions, Text: AC
# --------------------------------------------------
# Document Text: DROVER ' S LICENGE and SERVIIGES - GAIRID
# Br ritish Columbia
# CANS
# DL : 5469271
# DOB : 1953 - NOV - 30
# Issued : 2014 - MAR - 18
# Exp ires : 2024 - MAR - 18
# Res triction/
# Endorsements : 21
# Class : 5
# BRITISH
# COLUMBIA
# Wt : 58 . 0 kg
# Sex : M
# Ht : 176 cm
# 1958
# Eyes : BRN
# Hair : BRN
# 3631 MCKECHNIE AVE
# Tlomes Smilh WEST VANCOUVER BC V7V - 2N1
# Label: State, Text: Br ritish Columbia
# Label: Country, Text: CANS
# Label: License_Number, Text: 5469271
# Label: Endorsement, Text: 21
# Label: Class, Text: 5
# Label: State, Text: BRITISH
# COLUMBIA
# Label: Weight, Text: 58 . 0 kg
# Label: Sex, Text: M
# Label: Height, Text: 176 cm
# Label: Eyes, Text: BRN
# Label: Hair, Text: BRN
# Label: Address, Text: 3631 MCKECHNIE AVE
# Tlomes Smilh WEST VANCOUVER BC V7V - 2N1
# --------------------------------------------------
# Document Text: Driver
# ucend - No
# j U 216 *
# Licence
# JONES MARGARET CHERYL
# 50 SMITH ST
# SMITHVILLE QLD 9999
# itninre
# aply
# 26-03-80 F 170
# 01-07-2006 30-06-2011
# Queensland
# Goverament
# eens and Transport
# Label: Last_Name, Text: JONES
# Label: First_Name, Text: MARGARET CHERYL
# Label: Address, Text: 50 SMITH ST
# SMITHVILLE QLD 9999
# Label: Sex, Text: F
# Label: Height, Text: 170
# Label: State, Text: Queensland
# --------------------------------------------------
# Document Text: DRIVER LICENCE
# TASMANIA AUSTRALIA
# Tasmanial
# LIC . NO a 55269271
# D . O . B :
# 15NOV1972
# FULLC , EXP IRES 31 MAR 2010
# CITIZENE Last Name
# JOSEPHI
# First Name .
# 100TASMANIA ROADI Ã Ã
# SNUG 7054
# DEPARIMENT OF INFRASTRUCTURE , ENERGY AND RE SOURCES
# Label: State, Text: TASMANIA
# Label: Country, Text: AUSTRALIA
# Label: License_Number, Text: 55269271
# Label: First_Name, Text: JOSEPHI
# Label: Last_Name, Text: CITIZENE
# Label: Address, Text: 100TASMANIA ROADI Ã Ã
# SNUG 7054
# --------------------------------------------------
# Document Text: Driver Licence
# LICENCE NO :
# 118 - 5099 -
# BORISOVA
# VALENTINA
# DOB 16 Nov 1984 Sex F
# Height 168
# Class Type Effective
# Exp iry
# C
# 19 . 06 . 15 18 . 06 . 18
# Condirions
# -
# Queensland
# Government
# Queenstond , Australia
# Drive safely
# Label: License_Number, Text: 118 - 5099
# Label: Last_Name, Text: BORISOVA
# Label: First_Name, Text: VALENTINA
# Label: Sex, Text: F
# Label: Height, Text: 168
# Label: Class, Text: C
# Label: State, Text: Queensland
# Label: State, Text: Queenstond
# Label: Country, Text: Australia
# --------------------------------------------------
# Document Text: DRIVER LICENCE
# VICTORIA AUSTRALIA
# ZHANG
# LIU
# LICENCE NO .
# 051395622
# 2MONTCLAIR CLOSE
# SPRINGVALE SOUTHVIC3172
# LICENCE EXP IRY
# 21-03-2024
# DATEOF BIRTH
# 20-08-1995
# LICENCE TYPE
# CONDITIONS
# CAR
# avicroads
# Label: State, Text: VICTORIA
# Label: Country, Text: AUSTRALIA
#
# Label: License_Number, Text: 051395622
# Label: Last_Name, Text: ZHANG
# Label: First_Name, Text: LIU
# Label: Address, Text: SPRINGVALE SOUTHVIC3172
# Label: Address, Text: 2MONTCLAIR CLOSE
# Label: License_Type, Text: CAR
# --------------------------------------------------
# Document Text: ORIVER ' S LICENCE
# WESTERN AUSTRALIA
# Departimentof
# Transport
# ERN
# LICENCENUMBER
# 6275047
# FAKES .
# OLDIRONSIDES MIDDLE
# 4RAILWAYPARADE
# WESTLEEDERVILLE WA 6007
# EXP IRY DATE
# 29 Oct2023
# DATE OF BIRTH
# 05 May 2000
# CLASS
# C
# -
# 05052000
# Label: License_Number, Text: 6275047
# Label: Class, Text: C
# Label: State, Text: WESTERN AUSTRALIA
# Label: Last_Name, Text: FAKES
# Label: First_Name, Text: OLDIRONSIDES MIDDLE
# Label: Address, Text: 4RAILWAYPARADE
# WESTLEEDERVILLE WA 6007
# Label: Document_Number, Text: 05052000
# --------------------------------------------------

# %%
# 2. Label Statistics
editor.label_stats()
# Out:
# Label: Country, Count: 390
# Label: State, Count: 528
# Label: Address, Count: 695
# Label: Sex, Count: 424
# Label: Height, Count: 433
# Label: Restrictions, Count: 347
# Label: Endorsement, Count: 348
# Label: DD, Count: 316
# Label: Class, Count: 383
# Label: License_Number, Count: 593
# Label: Last_Name, Count: 607
# Label: First_Name, Count: 615
# Label: Document_Number, Count: 184
# Label: Eyes, Count: 412
# Label: Weight, Count: 245
# Label: Other, Count: 234
# Label: Hair, Count: 127
# Label: License_Type, Count: 30
# Label: Race, Count: 1
# Label: Birth_Place, Count: 111
# Label: Authority, Count: 118
# Label: Issuance_Number, Count: 35
# Label: DL_Class, Count: 113
#
# Total number of annotations found: 7289
# Total number of unique tags: 23

# %%
# 3. Search Annotations with a specific label
editor.search_by_label('B-PER')
# Out:
# Line 3: Hulls -X- _ B-PER
# Line 188: Areces -X- _ B-PER
# Line 195: Juan -X- _ B-PER
# Line 442: Jaime -X- _ B-PER
# Line 446: Chevenement -X- _ B-PER
# Line 680: Luis -X- _ B-PER
# Line 749: Conchita -X- _ B-PER
# Line 764: Martina -X- _ B-PER
# Line 809: SuÃ¡rez -X- _ B-PER
# ...
# Line 109121: Samani -X- _ B-PER
#
# Number of tokens found with label 'B-PER': 1669
# Number of sentences containing label 'B-PER': 1079

# %%
# 4. Search Annotations with a specific label
editor.search_by_token("Florida")
# Out:
# Line 26203: Florida -X- _ B-LOC
#
# Number of tokens found with 'Florida': 1
# Number of sentences containing 'Florida': 1

# %%
# 5. Remove specific label
editor.remove_label('B-PER')
# Out:
# Label 'B-PER' removed.

# %%
# 6. Merge multiple labels into one
editor.merge_labels(['B-MISC', 'I-MISC', 'B-ORG'], 'C-MISC')
# Out:
# Labels ['B-MISC', 'I-MISC', 'B-ORG'] merged into 'C-MISC'.

# %%
# Rechecking Label Statistics
editor.label_stats()
# Out:
# Label: O, Count: 236241
# Label: C-MISC, Count: 12775
# Label: B-LOC, Count: 4913
# Label: I-ORG, Count: 4992
# Label: I-LOC, Count: 1891
# Label: I-PER, Count: 3903
#
# Total number of labels found: 264715

# %%
# 7. Rename labels based on JSON mapping
editor.rename_labels({
    'I-PER':'A-MISC',
    'B-LOC':'A-LOC'
})
# Out:
# Labels renamed according to {'I-PER': 'A-MISC', 'B-LOC': 'A-LOC'}.

# %%
# Rechecking Label Statistics
editor.label_stats()
# Out:
# Label: O, Count: 236241
# Label: C-MISC, Count: 12775
# Label: A-LOC, Count: 4913
# Label: I-ORG, Count: 4992
# Label: I-LOC, Count: 1891
# Label: A-MISC, Count: 3903
#
# Total number of labels found: 264715

# %%
# 8. Delete an entire sentence containing an specific label
editor.delete_sentences_with_label("I-LOC")
# Out:
# Sentences containing the label 'I-LOC' have been deleted.
# Number of sentences deleted: 413
# Number of tokens deleted: 14029

# %%
# 9. Delete an entire sentence containing no label
editor.delete_sentences_without_annotations()
# Out:
# Sentences without annotations have been deleted successfully.
# Number of sentences deleted: 2123
# Number of tokens deleted: 31337

# %%
# Save the updated CoNLL file
editor.save('updated_file.json')
# Out:
# Updated file saved to updated_conll_file.conll
